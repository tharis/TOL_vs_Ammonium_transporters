# %%
# !mkdir 07_uncultured_aa
# !mkdir 07_uncultured_nt

# %%
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_aa/helix1.fasta > 07_uncultured_aa/helix1.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_aa/helix2.fasta > 07_uncultured_aa/helix2.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_aa/helix3.fasta > 07_uncultured_aa/helix3.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_aa/helix4.fasta > 07_uncultured_aa/helix4.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_aa/helix5.fasta > 07_uncultured_aa/helix5.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_aa/helix6.fasta > 07_uncultured_aa/helix6.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_aa/helix7.fasta > 07_uncultured_aa/helix7.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_aa/helix8.fasta > 07_uncultured_aa/helix8.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_aa/helix9.fasta > 07_uncultured_aa/helix9.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_aa/helix10.fasta > 07_uncultured_aa/helix10.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_aa/helix11.fasta > 07_uncultured_aa/helix11.fasta
# Out:
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file

# %%
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_nt/helix1.fasta > 07_uncultured_nt/helix1.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_nt/helix2.fasta > 07_uncultured_nt/helix2.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_nt/helix3.fasta > 07_uncultured_nt/helix3.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_nt/helix4.fasta > 07_uncultured_nt/helix4.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_nt/helix5.fasta > 07_uncultured_nt/helix5.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_nt/helix6.fasta > 07_uncultured_nt/helix6.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_nt/helix7.fasta > 07_uncultured_nt/helix7.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_nt/helix8.fasta > 07_uncultured_nt/helix8.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_nt/helix9.fasta > 07_uncultured_nt/helix9.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_nt/helix10.fasta > 07_uncultured_nt/helix10.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_nt/helix11.fasta > 07_uncultured_nt/helix11.fasta
# Out:
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file

# %%
# !mkdir 08_alignment

# %%
# !mafft --op 5 --ep 2.5 07_uncultured_aa/helix1.fasta > 08_alignment/helix1.fasta
# !mafft --op 5 --ep 2.5 07_uncultured_aa/helix2.fasta > 08_alignment/helix2.fasta
# !mafft --op 5 --ep 2.5 07_uncultured_aa/helix3.fasta > 08_alignment/helix3.fasta
# !mafft --op 5 --ep 2.5 07_uncultured_aa/helix4.fasta > 08_alignment/helix4.fasta
# !mafft --op 5 --ep 2.5 07_uncultured_aa/helix5.fasta > 08_alignment/helix5.fasta
# !mafft --op 5 --ep 2.5 07_uncultured_aa/helix6.fasta > 08_alignment/helix6.fasta
# !mafft --op 5 --ep 2.5 07_uncultured_aa/helix7.fasta > 08_alignment/helix7.fasta
# !mafft --op 5 --ep 2.5 07_uncultured_aa/helix8.fasta > 08_alignment/helix8.fasta
# !mafft --op 5 --ep 2.5 07_uncultured_aa/helix9.fasta > 08_alignment/helix9.fasta
# !mafft --op 5 --ep 2.5 07_uncultured_aa/helix10.fasta > 08_alignment/helix10.fasta
# !mafft --op 5 --ep 2.5 07_uncultured_aa/helix11.fasta > 08_alignment/helix11.fasta
# Out:
# nthread = 0
# nthreadpair = 0
# nthreadtb = 0
# ppenalty_ex = 0
# stacksize: 8192 kb
# rescale = 1
# Gap Penalty = -5.00, +0.00, -2.50
#
#
#
# Making a distance matrix ..
#   501 / 598
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#   590 / 598
# done.
#
# Progressive alignment 1/2...
# STEP   501 / 597
# Reallocating..done. *alloclen = 1059
#
# done.
#
# Making a distance matrix from msa..
#   500 / 598
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#   590 / 598
# done.
#
# Progressive alignment 2/2...
# STEP   501 / 597
# Reallocating..done. *alloclen = 1057
#
# done.
#
# disttbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 5.00, +2.50, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# ...

# %%
# !mkdir 09_tcoffee

# %%
# !t_coffee -other_pg seq_reformat -in 07_uncultured_nt/helix1.fasta -in2 08_alignment/helix1.fasta -action +thread_dna_on_prot_aln -output fasta > 09_tcoffee/helix1.fasta
# !t_coffee -other_pg seq_reformat -in 07_uncultured_nt/helix2.fasta -in2 08_alignment/helix2.fasta -action +thread_dna_on_prot_aln -output fasta > 09_tcoffee/helix2.fasta
# !t_coffee -other_pg seq_reformat -in 07_uncultured_nt/helix3.fasta -in2 08_alignment/helix3.fasta -action +thread_dna_on_prot_aln -output fasta > 09_tcoffee/helix3.fasta
# !t_coffee -other_pg seq_reformat -in 07_uncultured_nt/helix4.fasta -in2 08_alignment/helix4.fasta -action +thread_dna_on_prot_aln -output fasta > 09_tcoffee/helix4.fasta
# !t_coffee -other_pg seq_reformat -in 07_uncultured_nt/helix5.fasta -in2 08_alignment/helix5.fasta -action +thread_dna_on_prot_aln -output fasta > 09_tcoffee/helix5.fasta
# !t_coffee -other_pg seq_reformat -in 07_uncultured_nt/helix6.fasta -in2 08_alignment/helix6.fasta -action +thread_dna_on_prot_aln -output fasta > 09_tcoffee/helix6.fasta
# !t_coffee -other_pg seq_reformat -in 07_uncultured_nt/helix7.fasta -in2 08_alignment/helix7.fasta -action +thread_dna_on_prot_aln -output fasta > 09_tcoffee/helix7.fasta
# !t_coffee -other_pg seq_reformat -in 07_uncultured_nt/helix8.fasta -in2 08_alignment/helix8.fasta -action +thread_dna_on_prot_aln -output fasta > 09_tcoffee/helix8.fasta
# !t_coffee -other_pg seq_reformat -in 07_uncultured_nt/helix9.fasta -in2 08_alignment/helix9.fasta -action +thread_dna_on_prot_aln -output fasta > 09_tcoffee/helix9.fasta
# !t_coffee -other_pg seq_reformat -in 07_uncultured_nt/helix10.fasta -in2 08_alignment/helix10.fasta -action +thread_dna_on_prot_aln -output fasta > 09_tcoffee/helix10.fasta
# !t_coffee -other_pg seq_reformat -in 07_uncultured_nt/helix11.fasta -in2 08_alignment/helix11.fasta -action +thread_dna_on_prot_aln -output fasta > 09_tcoffee/helix11.fasta

# %%
# !mkdir 010_trim

# %%
# !trimal -in 09_tcoffee/helix1.fasta -out 010_trim/helix1.fasta -automated1
# !trimal -in 09_tcoffee/helix2.fasta -out 010_trim/helix2.fasta -automated1
# !trimal -in 09_tcoffee/helix3.fasta -out 010_trim/helix3.fasta -automated1
# !trimal -in 09_tcoffee/helix4.fasta -out 010_trim/helix4.fasta -automated1
# !trimal -in 09_tcoffee/helix5.fasta -out 010_trim/helix5.fasta -automated1
# !trimal -in 09_tcoffee/helix6.fasta -out 010_trim/helix6.fasta -automated1
# !trimal -in 09_tcoffee/helix7.fasta -out 010_trim/helix7.fasta -automated1
# !trimal -in 09_tcoffee/helix8.fasta -out 010_trim/helix8.fasta -automated1
# !trimal -in 09_tcoffee/helix9.fasta -out 010_trim/helix9.fasta -automated1
# !trimal -in 09_tcoffee/helix10.fasta -out 010_trim/helix10.fasta -automated1
# !trimal -in 09_tcoffee/helix11.fasta -out 010_trim/helix11.fasta -automated1

# %%
# !mkdir 011_concat_tree

# %%
# !seqkit concat 09_tcoffee/helix1.fasta 09_tcoffee/helix2.fasta 09_tcoffee/helix3.fasta 09_tcoffee/helix4.fasta 09_tcoffee/helix5.fasta 09_tcoffee/helix6.fasta 09_tcoffee/helix7.fasta 09_tcoffee/helix8.fasta 09_tcoffee/helix9.fasta 09_tcoffee/helix10.fasta 09_tcoffee/helix10.fasta > 011_concat_tree/helixconcat.fasta
# Out:
# [INFO] read file: 09_tcoffee/helix1.fasta
# [INFO] 598 records loaded from file: 09_tcoffee/helix1.fasta
# [INFO] read file: 09_tcoffee/helix2.fasta
# [INFO] 598 records loaded from file: 09_tcoffee/helix2.fasta
# [INFO] read file: 09_tcoffee/helix3.fasta
# [INFO] 598 records loaded from file: 09_tcoffee/helix3.fasta
# [INFO] read file: 09_tcoffee/helix4.fasta
# [INFO] 598 records loaded from file: 09_tcoffee/helix4.fasta
# [INFO] read file: 09_tcoffee/helix5.fasta
# [INFO] 598 records loaded from file: 09_tcoffee/helix5.fasta
# [INFO] read file: 09_tcoffee/helix6.fasta
# [INFO] 598 records loaded from file: 09_tcoffee/helix6.fasta
# [INFO] read file: 09_tcoffee/helix7.fasta
# [INFO] 598 records loaded from file: 09_tcoffee/helix7.fasta
# [INFO] read file: 09_tcoffee/helix8.fasta
# [INFO] 598 records loaded from file: 09_tcoffee/helix8.fasta
# [INFO] read file: 09_tcoffee/helix9.fasta
# [INFO] 598 records loaded from file: 09_tcoffee/helix9.fasta
# ...

# %%
# !seqkit rmdup -s 011_concat_tree/helixconcat.fasta > 011_concat_tree/concatrmdup.fasta
# Out:
# [INFO] 37 duplicated records removed

# %%
# !modeltest-ng -p 5 -i 011_concat_tree/helixconcat.fasta
# Out:
#                              _      _ _            _      _   _  _____
#                             | |    | | |          | |    | \ | |/ ____|
#          _ __ ___   ___   __| | ___| | |_ ___  ___| |_   |  \| | |  __
#         | '_ ` _ \ / _ \ / _` |/ _ \ | __/ _ \/ __| __|  | . ` | | |_ |
#         | | | | | | (_) | (_| |  __/ | ||  __/\__ \ |_   | |\  | |__| |
#         |_| |_| |_|\___/ \__,_|\___|_|\__\___||___/\__|  |_| \_|\_____|
# --------------------------------------------------------------------------------
# modeltest x.y.z
# Copyright (C) 2017 Diego Darriba, David Posada, Alexandros Stamatakis
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
#
# Written by Diego Darriba.
# --------------------------------------------------------------------------------
#
# Physical cores: 6
# Logical cores:  12
# Memory:         16GB
# ...

# %%
# !raxml-ng --check --msa 011_concat_tree/helixconcat.fasta --model TPM1uf+I+G4 --prefix 01_check
# Out:
# RAxML-NG v. 0.9.0 released on 20.05.2019 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# RAxML-NG was called at 08-Apr-2025 16:53:13 as follows:
#
# raxml-ng --check --msa 011_concat_tree/helixconcat.fasta --model TPM1uf+I+G4 --prefix 01_check
#
# Analysis options:
#   run mode: Alignment validation
#   start tree(s):
#   random seed: 1744127593
#   SIMD kernels: AVX2
#   parallelization: PTHREADS (6 threads), thread pinning: OFF
#
# [00:00:00] Reading alignment from file: 011_concat_tree/helixconcat.fasta
# [00:00:00] Loaded alignment with 598 taxa and 1053 sites
#
# WARNING: Sequences tr|A0A256HU74|A0A256HU74_9EURY and tr|A0A256HXJ0|A0A256HXJ0_9EURY are exactly identical!
# ...

# %%
# !raxml-ng --parse --msa 011_concat_tree/helixconcat.fasta --model TPM1uf+I+G4 --prefix 02_parse
# Out:
# RAxML-NG v. 0.9.0 released on 20.05.2019 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# RAxML-NG was called at 08-Apr-2025 16:54:26 as follows:
#
# raxml-ng --parse --msa 011_concat_tree/helixconcat.fasta --model TPM1uf+I+G4 --prefix 02_parse
#
# Analysis options:
#   run mode: Alignment parsing and compression
#   start tree(s):
#   random seed: 1744127666
#   tip-inner: OFF
#   pattern compression: ON
#   per-rate scalers: OFF
#   site repeats: ON
#   branch lengths: proportional (ML estimate, algorithm: NR-FAST)
#   SIMD kernels: AVX2
#   parallelization: PTHREADS (6 threads), thread pinning: OFF
#
# [00:00:00] Reading alignment from file: 011_concat_tree/helixconcat.fasta
# ...

# %%
# !raxml-ng --msa 02_parse.raxml.rba --model TPM1uf+I+G4 --all --bs-trees 100 --seed 1744127666 --prefix 03_bootstrap

# %%
# !raxml-ng --support --tree 011_concat_tree/08-04-25_amt_tree/03_bootstrap.raxml.bestTree --bs-trees 011_concat_tree/08-04-25_amt_tree/03_bootstrap.raxml.bootstraps --bs-metric TBE
# Out:
# RAxML-NG v. 0.9.0 released on 20.05.2019 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# RAxML-NG was called at 09-Apr-2025 07:43:43 as follows:
#
# raxml-ng --support --tree 011_concat_tree/08-04-25_amt_tree/03_bootstrap.raxml.bestTree --bs-trees 011_concat_tree/08-04-25_amt_tree/03_bootstrap.raxml.bootstraps --bs-metric TBE
#
# Analysis options:
#   run mode: Compute bipartition support (Transfer Bootstrap)
#   start tree(s): user
#   random seed: 1744181023
#   SIMD kernels: AVX2
#   parallelization: PTHREADS (6 threads), thread pinning: OFF
#
# Reading reference tree from file: 011_concat_tree/08-04-25_amt_tree/03_bootstrap.raxml.bestTree
# Reference tree size: 598
#
# ...
