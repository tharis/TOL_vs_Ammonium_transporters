# %%
# !mkdir 07_uncultured_nt
# !mkdir 07_uncultured_aa

# %%
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_aa/nitrogen_full.fasta > 07_uncultured_aa/nitrogen.fasta
# !seqkit grep --invert-match -f uncultered_to_remove.txt 02_header_nt/nitrogen_full.fasta > 07_uncultured_nt/nitrogen.fasta
# Out:
# [INFO] 71 patterns loaded from file
# [INFO] 71 patterns loaded from file

# %%
# !mkdir 08_alignment
# !mafft 07_uncultured_aa/nitrogen.fasta > 08_alignment/nitrogen.fasta
# Out:
# mkdir: 08_alignment: File exists
# nthread = 0
# nthreadpair = 0
# nthreadtb = 0
# ppenalty_ex = 0
# stacksize: 8192 kb
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#
# There are 7 ambiguous characters.
#   801 / 864
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#   860 / 864
# done.
#
# Progressive alignment 1/2...
# STEP   801 / 863  h
# Reallocating..done. *alloclen = 1223
#
# done.
#
# Making a distance matrix from msa..
#   800 / 864
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#   860 / 864
# done.
#
# Progressive alignment 2/2...
# STEP   801 / 863
# done.
#
# disttbfast (aa) Version 7.520
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# ...

# %%
# !mkdir 09_t-coffee

# %%
# !t_coffee -other_pg seq_reformat -in 07_uncultured_nt/nitrogen.fasta -in2 08_alignment/nitrogen.fasta -action +thread_dna_on_prot_aln -output fasta > 09_t-coffee/nitrogen.fasta

# %%
# !mkdir 010_tree

# %%
# !seqkit rmdup -s 09_t-coffee/nitrogen.fasta > 010_tree/nitrogen_rmdup.fasta
# Out:
# [INFO] 103 duplicated records removed

# %%
# !cd 010_tree/

# %%
# !cd ..

# %%
# !modeltest-ng -p 5 -i 010_tree/nitrogen.fasta
# Out:
#                              _      _ _            _      _   _  _____
#                             | |    | | |          | |    | \ | |/ ____|
#          _ __ ___   ___   __| | ___| | |_ ___  ___| |_   |  \| | |  __
#         | '_ ` _ \ / _ \ / _` |/ _ \ | __/ _ \/ __| __|  | . ` | | |_ |
#         | | | | | | (_) | (_| |  __/ | ||  __/\__ \ |_   | |\  | |__| |
#         |_| |_| |_|\___/ \__,_|\___|_|\__\___||___/\__|  |_| \_|\_____|
# --------------------------------------------------------------------------------
# modeltest x.y.z
# Copyright (C) 2017 Diego Darriba, David Posada, Alexandros Stamatakis
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
#
# Written by Diego Darriba.
# --------------------------------------------------------------------------------
#
# Physical cores: 6
# Logical cores:  12
# Memory:         16GB
# ...

# %%
# !raxml-ng --check --msa 010_tree/nitrogen.fasta --model SYM+I+G4 --prefix 01_check
# Out:
# RAxML-NG v. 0.9.0 released on 20.05.2019 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# RAxML-NG was called at 08-Apr-2025 16:20:36 as follows:
#
# raxml-ng --check --msa 010_tree/nitrogen.fasta --model SYM+I+G4 --prefix 01_check
#
# Analysis options:
#   run mode: Alignment validation
#   start tree(s):
#   random seed: 1744125636
#   SIMD kernels: AVX2
#   parallelization: PTHREADS (6 threads), thread pinning: OFF
#
# [00:00:00] Reading alignment from file: 010_tree/nitrogen.fasta
# [00:00:00] Loaded alignment with 864 taxa and 348 sites
#
# WARNING: Sequences tr|A0A099I9L1|A0A099I9L1_CLOIN and tr|A0A1C7HSA7|A0A1C7HSA7_9FIRM are exactly identical!
# ...

# %%
# !raxml-ng --parse --msa 010_tree/nitrogen.fasta --model SYM+I+G4 --prefix 02_parse
# Out:
# RAxML-NG v. 0.9.0 released on 20.05.2019 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# RAxML-NG was called at 08-Apr-2025 16:21:11 as follows:
#
# raxml-ng --parse --msa 010_tree/nitrogen.fasta --model SYM+I+G4 --prefix 02_parse
#
# Analysis options:
#   run mode: Alignment parsing and compression
#   start tree(s):
#   random seed: 1744125671
#   tip-inner: OFF
#   pattern compression: ON
#   per-rate scalers: OFF
#   site repeats: ON
#   branch lengths: proportional (ML estimate, algorithm: NR-FAST)
#   SIMD kernels: AVX2
#   parallelization: PTHREADS (6 threads), thread pinning: OFF
#
# [00:00:00] Reading alignment from file: 010_tree/nitrogen.fasta
# ...

# %%
# !raxml-ng --threads 25 --msa 02_parse.raxml.rba --model SYM+I+G4 --all --bs-trees 100 --seed 1744125671 --prefix 03_bootstrap

# %%
# !raxml-ng --support --tree 010_tree/08-04-25_nit_tree/03_bootstrap.raxml.bestTree --bs-trees 010_tree/08-04-25_nit_tree/03_bootstrap.raxml.bootstraps --bs-metric TBE
# Out:
# RAxML-NG v. 0.9.0 released on 20.05.2019 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# RAxML-NG was called at 09-Apr-2025 07:42:11 as follows:
#
# raxml-ng --support --tree 010_tree/08-04-25_nit_tree/03_bootstrap.raxml.bestTree --bs-trees 010_tree/08-04-25_nit_tree/03_bootstrap.raxml.bootstraps --bs-metric TBE
#
# Analysis options:
#   run mode: Compute bipartition support (Transfer Bootstrap)
#   start tree(s): user
#   random seed: 1744180931
#   SIMD kernels: AVX2
#   parallelization: PTHREADS (6 threads), thread pinning: OFF
#
# Reading reference tree from file: 010_tree/08-04-25_nit_tree/03_bootstrap.raxml.bestTree
# Reference tree size: 864
#
# ...
