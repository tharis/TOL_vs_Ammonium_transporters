# %%
# !modeltest-ng -p 5 -i concatrmdup.fasta
# Out:
#                              _      _ _            _      _   _  _____
#                             | |    | | |          | |    | \ | |/ ____|
#          _ __ ___   ___   __| | ___| | |_ ___  ___| |_   |  \| | |  __
#         | '_ ` _ \ / _ \ / _` |/ _ \ | __/ _ \/ __| __|  | . ` | | |_ |
#         | | | | | | (_) | (_| |  __/ | ||  __/\__ \ |_   | |\  | |__| |
#         |_| |_| |_|\___/ \__,_|\___|_|\__\___||___/\__|  |_| \_|\_____|
# --------------------------------------------------------------------------------
# modeltest x.y.z
# Copyright (C) 2017 Diego Darriba, David Posada, Alexandros Stamatakis
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
#
# Written by Diego Darriba.
# --------------------------------------------------------------------------------
#
# Physical cores: 6
# Logical cores:  12
# Memory:         16GB
# ...

# %%
# !raxml-ng --check --msa concatrmdup.fasta --model TPM1uf+I+G4 --prefix 01_check
# Out:
# RAxML-NG v. 0.9.0 released on 20.05.2019 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# RAxML-NG was called at 16-Jul-2025 12:00:23 as follows:
#
# raxml-ng --check --msa concatrmdup.fasta --model TPM1uf+I+G4 --prefix 01_check
#
# Analysis options:
#   run mode: Alignment validation
#   start tree(s):
#   random seed: 1752663623
#   SIMD kernels: AVX2
#   parallelization: PTHREADS (6 threads), thread pinning: OFF
#
# [00:00:00] Reading alignment from file: concatrmdup.fasta
# [00:00:00] Loaded alignment with 1533 taxa and 581 sites
#
# Alignment comprises 1 partitions and 581 patterns
#
# Partition 0: noname
# Model: K81uf+FO+I+G4m
# Alignment sites / patterns: 581 / 581
# Gaps: 8.26 %
# ...

# %%
# !raxml-ng --parse --msa concatrmdup.fasta --model TPM1uf+I+G4 --prefix 02_parse
# Out:
# RAxML-NG v. 0.9.0 released on 20.05.2019 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# RAxML-NG was called at 16-Jul-2025 12:00:26 as follows:
#
# raxml-ng --parse --msa concatrmdup.fasta --model TPM1uf+I+G4 --prefix 02_parse
#
# Analysis options:
#   run mode: Alignment parsing and compression
#   start tree(s):
#   random seed: 1752663626
#   tip-inner: OFF
#   pattern compression: ON
#   per-rate scalers: OFF
#   site repeats: ON
#   branch lengths: proportional (ML estimate, algorithm: NR-FAST)
#   SIMD kernels: AVX2
#   parallelization: PTHREADS (6 threads), thread pinning: OFF
#
# [00:00:00] Reading alignment from file: concatrmdup.fasta
# [00:00:00] Loaded alignment with 1533 taxa and 581 sites
#
# ...
