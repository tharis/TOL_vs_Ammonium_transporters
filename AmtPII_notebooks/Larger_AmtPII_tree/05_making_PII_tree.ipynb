# %%
# !seqkit rmdup -s nitrogen.fasta > nitrogenrmdup.fasta
# Out:
# [INFO] 180 duplicated records removed

# %%
# !modeltest-ng -p 5 -i nitrogenrmdup.fasta
# Out:
#                              _      _ _            _      _   _  _____
#                             | |    | | |          | |    | \ | |/ ____|
#          _ __ ___   ___   __| | ___| | |_ ___  ___| |_   |  \| | |  __
#         | '_ ` _ \ / _ \ / _` |/ _ \ | __/ _ \/ __| __|  | . ` | | |_ |
#         | | | | | | (_) | (_| |  __/ | ||  __/\__ \ |_   | |\  | |__| |
#         |_| |_| |_|\___/ \__,_|\___|_|\__\___||___/\__|  |_| \_|\_____|
# --------------------------------------------------------------------------------
# modeltest x.y.z
# Copyright (C) 2017 Diego Darriba, David Posada, Alexandros Stamatakis
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>.
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
#
# Written by Diego Darriba.
# --------------------------------------------------------------------------------
#
# Physical cores: 6
# Logical cores:  12
# Memory:         16GB
# ...

# %%
# !raxml-ng --check --msa nitrogenrmdup.fasta --model TPM1uf+I+G4 --prefix 01_check
# Out:
# RAxML-NG v. 0.9.0 released on 20.05.2019 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# RAxML-NG was called at 14-Jul-2025 14:05:30 as follows:
#
# raxml-ng --check --msa nitrogenrmdup.fasta --model TPM1uf+I+G4 --prefix 01_check
#
# Analysis options:
#   run mode: Alignment validation
#   start tree(s):
#   random seed: 1752498330
#   SIMD kernels: AVX2
#   parallelization: PTHREADS (6 threads), thread pinning: OFF
#
# [00:00:00] Reading alignment from file: nitrogenrmdup.fasta
# [00:00:00] Loaded alignment with 1683 taxa and 762 sites
#
# Alignment comprises 1 partitions and 762 patterns
#
# Partition 0: noname
# Model: K81uf+FO+I+G4m
# Alignment sites / patterns: 762 / 762
# Gaps: 56.92 %
# ...

# %%
# !raxml-ng --parse --msa nitrogenrmdup.fasta --model TPM1uf+I+G4 --prefix 02_parse
# Out:
# RAxML-NG v. 0.9.0 released on 20.05.2019 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# RAxML-NG was called at 14-Jul-2025 14:05:32 as follows:
#
# raxml-ng --parse --msa nitrogenrmdup.fasta --model TPM1uf+I+G4 --prefix 02_parse
#
# Analysis options:
#   run mode: Alignment parsing and compression
#   start tree(s):
#   random seed: 1752498332
#   tip-inner: OFF
#   pattern compression: ON
#   per-rate scalers: OFF
#   site repeats: ON
#   branch lengths: proportional (ML estimate, algorithm: NR-FAST)
#   SIMD kernels: AVX2
#   parallelization: PTHREADS (6 threads), thread pinning: OFF
#
# [00:00:00] Reading alignment from file: nitrogenrmdup.fasta
# [00:00:00] Loaded alignment with 1683 taxa and 762 sites
#
# ...

# %%
# !raxml-ng --msa 02_parse.raxml.rba --model TPM1uf+G4 --all --bs-trees 100 --seed 1752491070 --prefix 03_bootstrap
# Out:
# RAxML-NG v. 0.9.0 released on 20.05.2019 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# RAxML-NG was called at 14-Jul-2025 12:07:56 as follows:
#
# raxml-ng --msa 02_parse.raxml.rba --model TPM1uf+G4 --all --bs-trees 100 --seed 1752491070 --prefix 03_bootstrap
#
# Analysis options:
#   run mode: ML tree search + bootstrapping (Felsenstein Bootstrap)
#   start tree(s): random (10) + parsimony (10)
#   bootstrap replicates: 100
#   random seed: 1752491070
#   tip-inner: OFF
#   pattern compression: ON
#   per-rate scalers: OFF
#   site repeats: ON
#   branch lengths: proportional (ML estimate, algorithm: NR-FAST)
#   SIMD kernels: AVX2
#   parallelization: PTHREADS (6 threads), thread pinning: OFF
#
# ...
