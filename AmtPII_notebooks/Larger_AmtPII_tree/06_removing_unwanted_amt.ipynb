# %%
# !mkdir 07_headers_aa
# !mkdir 07_headers_nt

# %%
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_aa//helix1.fasta > 07_headers_aa//helix1.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_aa//helix2.fasta > 07_headers_aa//helix2.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_aa//helix3.fasta > 07_headers_aa//helix3.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_aa//helix4.fasta > 07_headers_aa//helix4.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_aa//helix5.fasta > 07_headers_aa//helix5.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_aa//helix6.fasta > 07_headers_aa//helix6.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_aa//helix7.fasta > 07_headers_aa//helix7.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_aa//helix8.fasta > 07_headers_aa//helix8.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_aa//helix9.fasta > 07_headers_aa//helix9.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_aa//helix10.fasta > 07_headers_aa//helix10.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_aa//helix11.fasta > 07_headers_aa//helix11.fasta

# %%
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_nt//helix1.fasta > 07_headers_nt//helix1.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_nt//helix2.fasta > 07_headers_nt//helix2.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_nt//helix3.fasta > 07_headers_nt//helix3.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_nt//helix4.fasta > 07_headers_nt//helix4.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_nt//helix5.fasta > 07_headers_nt//helix5.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_nt//helix6.fasta > 07_headers_nt//helix6.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_nt//helix7.fasta > 07_headers_nt//helix7.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_nt//helix8.fasta > 07_headers_nt//helix8.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_nt//helix9.fasta > 07_headers_nt//helix9.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_nt//helix10.fasta > 07_headers_nt//helix10.fasta
# !awk -F"/" '/^>/{print $1; next}1' 0101_combined_nt//helix11.fasta > 07_headers_nt//helix11.fasta

# %%
# !mkdir 01_removed_aa
# !mkdir 01_removed_nt

# !mkdir 02_alignemnt
# !mkdir 03_tcoffee
# !mkdir 05_concat

# %%
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_aa/helix1.fasta > 01_removed_aa/helix1.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_aa/helix2.fasta > 01_removed_aa/helix2.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_aa/helix3.fasta > 01_removed_aa/helix3.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_aa/helix4.fasta > 01_removed_aa/helix4.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_aa/helix5.fasta > 01_removed_aa/helix5.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_aa/helix6.fasta > 01_removed_aa/helix6.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_aa/helix7.fasta > 01_removed_aa/helix7.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_aa/helix8.fasta > 01_removed_aa/helix8.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_aa/helix9.fasta > 01_removed_aa/helix9.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_aa/helix10.fasta > 01_removed_aa/helix10.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_aa/helix11.fasta > 01_removed_aa/helix11.fasta
# Out:
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file

# %%
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_nt/helix1.fasta > 01_removed_nt/helix1.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_nt/helix2.fasta > 01_removed_nt/helix2.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_nt/helix3.fasta > 01_removed_nt/helix3.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_nt/helix4.fasta > 01_removed_nt/helix4.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_nt/helix5.fasta > 01_removed_nt/helix5.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_nt/helix6.fasta > 01_removed_nt/helix6.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_nt/helix7.fasta > 01_removed_nt/helix7.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_nt/helix8.fasta > 01_removed_nt/helix8.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_nt/helix9.fasta > 01_removed_nt/helix9.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_nt/helix10.fasta > 01_removed_nt/helix10.fasta
# !seqkit grep --invert-match -f to_remove_01.fasta 07_headers_nt/helix11.fasta > 01_removed_nt/helix11.fasta
# Out:
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file
# [INFO] 38 patterns loaded from file

# %%
# !mafft --op 5 --ep 2.5 01_removed_aa/helix1.fasta > 02_alignment/helix1.fasta
# !mafft --op 5 --ep 2.5 01_removed_aa/helix2.fasta > 02_alignment/helix2.fasta
# !mafft --op 5 --ep 2.5 01_removed_aa/helix3.fasta > 02_alignment/helix3.fasta
# !mafft --op 5 --ep 2.5 01_removed_aa/helix4.fasta > 02_alignment/helix4.fasta
# !mafft --op 5 --ep 2.5 01_removed_aa/helix5.fasta > 02_alignment/helix5.fasta
# !mafft --op 5 --ep 2.5 01_removed_aa/helix6.fasta > 02_alignment/helix6.fasta
# !mafft --op 5 --ep 2.5 01_removed_aa/helix7.fasta > 02_alignment/helix7.fasta
# !mafft --op 5 --ep 2.5 01_removed_aa/helix8.fasta > 02_alignment/helix8.fasta
# !mafft --op 5 --ep 2.5 01_removed_aa/helix9.fasta > 02_alignment/helix9.fasta
# !mafft --op 5 --ep 2.5 01_removed_aa/helix10.fasta > 02_alignment/helix10.fasta
# !mafft --op 5 --ep 2.5 01_removed_aa/helix11.fasta > 02_alignment/helix11.fasta
# Out:
# nthread = 0
# nthreadpair = 0
# nthreadtb = 0
# ppenalty_ex = 0
# stacksize: 8192 kb
# rescale = 1
# Gap Penalty = -5.00, +0.00, -2.50
#
#
#
# Making a distance matrix ..
#  1801 / 1859
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#  1850 / 1859
# done.
#
# Progressive alignment 1/2...
# STEP  1701 / 1858  h
# Reallocating..done. *alloclen = 1063
# STEP  1801 / 1858
# done.
#
# Making a distance matrix from msa..
#  1800 / 1859
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#  1850 / 1859
# done.
#
# Progressive alignment 2/2...
# STEP  1701 / 1858  h
# Reallocating..done. *alloclen = 1063
# STEP  1801 / 1858  h
# done.
#
# disttbfast (aa) Version 7.520
# alg=A, model=BLOSUM62, 5.00, +2.50, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# ...

# %%
# !t_coffee -other_pg seq_reformat -in 01_removed_nt/helix1.fasta -in2 02_alignment/helix1.fasta -action +thread_dna_on_prot_aln -output fasta > 03_tcoffee/helix1.fasta 
# !t_coffee -other_pg seq_reformat -in 01_removed_nt/helix2.fasta -in2 02_alignment/helix2.fasta -action +thread_dna_on_prot_aln -output fasta > 03_tcoffee/helix2.fasta 
# !t_coffee -other_pg seq_reformat -in 01_removed_nt/helix3.fasta -in2 02_alignment/helix3.fasta -action +thread_dna_on_prot_aln -output fasta > 03_tcoffee/helix3.fasta 
# !t_coffee -other_pg seq_reformat -in 01_removed_nt/helix4.fasta -in2 02_alignment/helix4.fasta -action +thread_dna_on_prot_aln -output fasta > 03_tcoffee/helix4.fasta 
# !t_coffee -other_pg seq_reformat -in 01_removed_nt/helix5.fasta -in2 02_alignment/helix5.fasta -action +thread_dna_on_prot_aln -output fasta > 03_tcoffee/helix5.fasta 
# !t_coffee -other_pg seq_reformat -in 01_removed_nt/helix6.fasta -in2 02_alignment/helix6.fasta -action +thread_dna_on_prot_aln -output fasta > 03_tcoffee/helix6.fasta 
# !t_coffee -other_pg seq_reformat -in 01_removed_nt/helix7.fasta -in2 02_alignment/helix7.fasta -action +thread_dna_on_prot_aln -output fasta > 03_tcoffee/helix7.fasta 
# !t_coffee -other_pg seq_reformat -in 01_removed_nt/helix8.fasta -in2 02_alignment/helix8.fasta -action +thread_dna_on_prot_aln -output fasta > 03_tcoffee/helix8.fasta 
# !t_coffee -other_pg seq_reformat -in 01_removed_nt/helix9.fasta -in2 02_alignment/helix9.fasta -action +thread_dna_on_prot_aln -output fasta > 03_tcoffee/helix9.fasta 
# !t_coffee -other_pg seq_reformat -in 01_removed_nt/helix10.fasta -in2 02_alignment/helix10.fasta -action +thread_dna_on_prot_aln -output fasta > 03_tcoffee/helix10.fasta 
# !t_coffee -other_pg seq_reformat -in 01_removed_nt/helix11.fasta -in2 02_alignment/helix11.fasta -action +thread_dna_on_prot_aln -output fasta > 03_tcoffee/helix11.fasta

# %%
# !mkdir 04_trimal

# %%
# !trimal -in 03_tcoffee/helix1.fasta -out 04_trimal/helix1.fasta -automated1
# !trimal -in 03_tcoffee/helix2.fasta -out 04_trimal/helix2.fasta -automated1
# !trimal -in 03_tcoffee/helix3.fasta -out 04_trimal/helix3.fasta -automated1
# !trimal -in 03_tcoffee/helix4.fasta -out 04_trimal/helix4.fasta -automated1
# !trimal -in 03_tcoffee/helix5.fasta -out 04_trimal/helix5.fasta -automated1
# !trimal -in 03_tcoffee/helix6.fasta -out 04_trimal/helix6.fasta -automated1
# !trimal -in 03_tcoffee/helix7.fasta -out 04_trimal/helix7.fasta -automated1
# !trimal -in 03_tcoffee/helix8.fasta -out 04_trimal/helix8.fasta -automated1
# !trimal -in 03_tcoffee/helix9.fasta -out 04_trimal/helix9.fasta -automated1
# !trimal -in 03_tcoffee/helix10.fasta -out 04_trimal/helix10.fasta -automated1
# !trimal -in 03_tcoffee/helix11.fasta -out 04_trimal/helix11.fasta -automated1
# Out:
# Error: the symbol 'S' accesing the matrix is not defined in this object
# Error: the symbol 'S' accesing the matrix is not defined in this object
# Error: the symbol 'S' accesing the matrix is not defined in this object
# Error: the symbol 'S' accesing the matrix is not defined in this object
# Error: the symbol 'S' accesing the matrix is not defined in this object
# Error: the symbol 'S' accesing the matrix is not defined in this object
# Error: the symbol 'S' accesing the matrix is not defined in this object
# Error: the symbol 'S' accesing the matrix is not defined in this object
# Error: the symbol 'S' accesing the matrix is not defined in this object
# Error: the symbol 'S' accesing the matrix is not defined in this object
# Error: the symbol 'S' accesing the matrix is not defined in this object
# Error: the symbol 'S' accesing the matrix is not defined in this object
# Error: the symbol 'S' accesing the matrix is not defined in this object
# ...

# %%
# !seqkit concat 04_trimal/helix1.fasta 04_trimal/helix2.fasta 04_trimal/helix3.fasta 04_trimal/helix4.fasta 04_trimal/helix5.fasta 04_trimal/helix6.fasta 04_trimal/helix7.fasta 04_trimal/helix8.fasta 04_trimal/helix9.fasta 04_trimal/helix10.fasta 04_trimal/helix11.fasta > 05_concat/concat.fasta
# Out:
# [INFO] read file: 04_trimal/helix1.fasta
# [INFO] 1859 records loaded from file: 04_trimal/helix1.fasta
# [INFO] read file: 04_trimal/helix2.fasta
# [INFO] 1856 records loaded from file: 04_trimal/helix2.fasta
# [INFO] read file: 04_trimal/helix3.fasta
# [INFO] 1857 records loaded from file: 04_trimal/helix3.fasta
# [INFO] read file: 04_trimal/helix4.fasta
# [INFO] 1857 records loaded from file: 04_trimal/helix4.fasta
# [INFO] read file: 04_trimal/helix5.fasta
# [INFO] 1856 records loaded from file: 04_trimal/helix5.fasta
# [INFO] read file: 04_trimal/helix6.fasta
# [INFO] 1856 records loaded from file: 04_trimal/helix6.fasta
# [INFO] read file: 04_trimal/helix7.fasta
# [INFO] 1854 records loaded from file: 04_trimal/helix7.fasta
# [INFO] read file: 04_trimal/helix8.fasta
# [INFO] 1855 records loaded from file: 04_trimal/helix8.fasta
# [INFO] read file: 04_trimal/helix9.fasta
# [INFO] 1855 records loaded from file: 04_trimal/helix9.fasta
# [INFO] read file: 04_trimal/helix10.fasta
# ...

# %%
# !seqkit rmdup -s 05_concat/concat.fasta > 05_concat/concatrmdup.fasta
# Out:
# [INFO] 2331504 duplicated records removed
