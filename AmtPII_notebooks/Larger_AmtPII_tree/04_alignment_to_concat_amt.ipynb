# %%
# !mkdir amt_alignments

# %%
# !mafft --op 5 --ep 2.5 0101_combined_aa/helix1.fasta > 02_amt_alignments/helix1.fasta
# Out:
# nthread = 0
# nthreadpair = 0
# nthreadtb = 0
# ppenalty_ex = 0
# stacksize: 8192 kb
# rescale = 1
# Gap Penalty = -5.00, +0.00, -2.50
#
#
#
# Making a distance matrix ..
#  1801 / 1899
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#  1890 / 1899
# done.
#
# Progressive alignment 1/2...
# STEP  1701 / 1898  h
# Reallocating..done. *alloclen = 1060
# STEP  1801 / 1898
# done.
#
# Making a distance matrix from msa..
#  1800 / 1899
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#  1890 / 1899
# done.
#
# Progressive alignment 2/2...
# STEP  1801 / 1898
# Reallocating..done. *alloclen = 1063
#
# done.
#
# disttbfast (aa) Version 7.520
# alg=A, model=BLOSUM62, 5.00, +2.50, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# ...

# %%
# !mafft --op 5 --ep 2.5 0101_combined_aa/helix2.fasta > 02_amt_alignments/helix2.fasta
# !mafft --op 5 --ep 2.5 0101_combined_aa/helix3.fasta > 02_amt_alignments/helix3.fasta
# !mafft --op 5 --ep 2.5 0101_combined_aa/helix4.fasta > 02_amt_alignments/helix4.fasta
# !mafft --op 5 --ep 2.5 0101_combined_aa/helix5.fasta > 02_amt_alignments/helix5.fasta
# !mafft --op 5 --ep 2.5 0101_combined_aa/helix6.fasta > 02_amt_alignments/helix6.fasta
# !mafft --op 5 --ep 2.5 0101_combined_aa/helix7.fasta > 02_amt_alignments/helix7.fasta
# !mafft --op 5 --ep 2.5 0101_combined_aa/helix8.fasta > 02_amt_alignments/helix8.fasta
# !mafft --op 5 --ep 2.5 0101_combined_aa/helix9.fasta > 02_amt_alignments/helix9.fasta
# !mafft --op 5 --ep 2.5 0101_combined_aa/helix10.fasta > 02_amt_alignments/helix10.fasta
# !mafft --op 5 --ep 2.5 0101_combined_aa/helix11.fasta > 02_amt_alignments/helix11.fasta
# Out:
# nthread = 0
# nthreadpair = 0
# nthreadtb = 0
# ppenalty_ex = 0
# stacksize: 8192 kb
# rescale = 1
# Gap Penalty = -5.00, +0.00, -2.50
#
#
#
# Making a distance matrix ..
#  1801 / 1896
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#  1890 / 1896
# done.
#
# Progressive alignment 1/2...
# STEP  1501 / 1895
# Reallocating..done. *alloclen = 1075
# STEP  1801 / 1895  h
# done.
#
# Making a distance matrix from msa..
#  1800 / 1896
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#  1890 / 1896
# done.
#
# Progressive alignment 2/2...
# STEP  1801 / 1895
# Reallocating..done. *alloclen = 1079
#
# done.
#
# disttbfast (aa) Version 7.520
# alg=A, model=BLOSUM62, 5.00, +2.50, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# ...

# %%
# !mkdir t_coffee

# %%
# !t_coffee -other_pg seq_reformat -in 0101_combined_nt/helix1.fasta -in2 02_amt_alignments/helix1.fasta -action +thread_dna_on_prot_aln -output fasta > 03_t_coffee/helix1.fasta

# %%
# !t_coffee -other_pg seq_reformat -in 0101_combined_nt/helix2.fasta -in2 02_amt_alignments/helix2.fasta -action +thread_dna_on_prot_aln -output fasta > 03_t_coffee/helix2.fasta 
# !t_coffee -other_pg seq_reformat -in 0101_combined_nt/helix3.fasta -in2 02_amt_alignments/helix3.fasta -action +thread_dna_on_prot_aln -output fasta > 03_t_coffee/helix3.fasta 
# !t_coffee -other_pg seq_reformat -in 0101_combined_nt/helix4.fasta -in2 02_amt_alignments/helix4.fasta -action +thread_dna_on_prot_aln -output fasta > 03_t_coffee/helix4.fasta 
# !t_coffee -other_pg seq_reformat -in 0101_combined_nt/helix5.fasta -in2 02_amt_alignments/helix5.fasta -action +thread_dna_on_prot_aln -output fasta > 03_t_coffee/helix5.fasta 
# !t_coffee -other_pg seq_reformat -in 0101_combined_nt/helix6.fasta -in2 02_amt_alignments/helix6.fasta -action +thread_dna_on_prot_aln -output fasta > 03_t_coffee/helix6.fasta 
# !t_coffee -other_pg seq_reformat -in 0101_combined_nt/helix7.fasta -in2 02_amt_alignments/helix7.fasta -action +thread_dna_on_prot_aln -output fasta > 03_t_coffee/helix7.fasta 
# !t_coffee -other_pg seq_reformat -in 0101_combined_nt/helix8.fasta -in2 02_amt_alignments/helix8.fasta -action +thread_dna_on_prot_aln -output fasta > 03_t_coffee/helix8.fasta 
# !t_coffee -other_pg seq_reformat -in 0101_combined_nt/helix9.fasta -in2 02_amt_alignments/helix9.fasta -action +thread_dna_on_prot_aln -output fasta > 03_t_coffee/helix9.fasta 
# !t_coffee -other_pg seq_reformat -in 0101_combined_nt/helix10.fasta -in2 02_amt_alignments/helix10.fasta -action +thread_dna_on_prot_aln -output fasta > 03_t_coffee/helix10.fasta 
# !t_coffee -other_pg seq_reformat -in 0101_combined_nt/helix11.fasta -in2 02_amt_alignments/helix11.fasta -action +thread_dna_on_prot_aln -output fasta > 03_t_coffee/helix11.fasta

# %%
# !mkdir 04_trimal

# %%
# !trimal -in 03_t_coffee/helix1.fasta -out 04_trimal/helix1.fasta -automated1
# !trimal -in 03_t_coffee/helix2.fasta -out 04_trimal/helix2.fasta -automated1
# !trimal -in 03_t_coffee/helix3.fasta -out 04_trimal/helix3.fasta -automated1
# !trimal -in 03_t_coffee/helix4.fasta -out 04_trimal/helix4.fasta -automated1
# !trimal -in 03_t_coffee/helix5.fasta -out 04_trimal/helix5.fasta -automated1
# !trimal -in 03_t_coffee/helix6.fasta -out 04_trimal/helix6.fasta -automated1
# !trimal -in 03_t_coffee/helix7.fasta -out 04_trimal/helix7.fasta -automated1
# !trimal -in 03_t_coffee/helix8.fasta -out 04_trimal/helix8.fasta -automated1
# !trimal -in 03_t_coffee/helix9.fasta -out 04_trimal/helix9.fasta -automated1
# !trimal -in 03_t_coffee/helix10.fasta -out 04_trimal/helix10.fasta -automated1
# !trimal -in 03_t_coffee/helix11.fasta -out 04_trimal/helix11.fasta -automated1

# %%
# !mkdir 05_nt_headers
# !mkdir 05_aa_headers

# %%
# !awk -F"/" '/^>/{print $1; next}1' 04_trimal/helix1.fasta > 05_nt_headers/helix1.fasta
# !awk -F"/" '/^>/{print $1; next}1' 04_trimal/helix2.fasta > 05_nt_headers/helix2.fasta
# !awk -F"/" '/^>/{print $1; next}1' 04_trimal/helix3.fasta > 05_nt_headers/helix3.fasta
# !awk -F"/" '/^>/{print $1; next}1' 04_trimal/helix4.fasta > 05_nt_headers/helix4.fasta
# !awk -F"/" '/^>/{print $1; next}1' 04_trimal/helix5.fasta > 05_nt_headers/helix5.fasta
# !awk -F"/" '/^>/{print $1; next}1' 04_trimal/helix6.fasta > 05_nt_headers/helix6.fasta
# !awk -F"/" '/^>/{print $1; next}1' 04_trimal/helix7.fasta > 05_nt_headers/helix7.fasta
# !awk -F"/" '/^>/{print $1; next}1' 04_trimal/helix8.fasta > 05_nt_headers/helix8.fasta
# !awk -F"/" '/^>/{print $1; next}1' 04_trimal/helix9.fasta > 05_nt_headers/helix9.fasta
# !awk -F"/" '/^>/{print $1; next}1' 04_trimal/helix10.fasta > 05_nt_headers/helix10.fasta
# !awk -F"/" '/^>/{print $1; next}1' 04_trimal/helix11.fasta > 05_nt_headers/helix11.fasta

# %%
# !awk -F"/" '/^>/{print $1; next}1' 02_amt_alignments/helix1.fasta > 05_aa_headers/helix1.fasta
# !awk -F"/" '/^>/{print $1; next}1' 02_amt_alignments/helix2.fasta > 05_aa_headers/helix2.fasta
# !awk -F"/" '/^>/{print $1; next}1' 02_amt_alignments/helix3.fasta > 05_aa_headers/helix3.fasta
# !awk -F"/" '/^>/{print $1; next}1' 02_amt_alignments/helix4.fasta > 05_aa_headers/helix4.fasta
# !awk -F"/" '/^>/{print $1; next}1' 02_amt_alignments/helix5.fasta > 05_aa_headers/helix5.fasta
# !awk -F"/" '/^>/{print $1; next}1' 02_amt_alignments/helix6.fasta > 05_aa_headers/helix6.fasta
# !awk -F"/" '/^>/{print $1; next}1' 02_amt_alignments/helix7.fasta > 05_aa_headers/helix7.fasta
# !awk -F"/" '/^>/{print $1; next}1' 02_amt_alignments/helix8.fasta > 05_aa_headers/helix8.fasta
# !awk -F"/" '/^>/{print $1; next}1' 02_amt_alignments/helix9.fasta > 05_aa_headers/helix9.fasta
# !awk -F"/" '/^>/{print $1; next}1' 02_amt_alignments/helix10.fasta > 05_aa_headers/helix10.fasta
# !awk -F"/" '/^>/{print $1; next}1' 02_amt_alignments/helix11.fasta > 05_aa_headers/helix11.fasta

# %%
# !mkdir 06_concat

# %%
# !seqkit concat 05_nt_headers/helix1.fasta 05_nt_headers/helix2.fasta 05_nt_headers/helix3.fasta 05_nt_headers/helix4.fasta 05_nt_headers/helix5.fasta 05_nt_headers/helix6.fasta 05_nt_headers/helix7.fasta 05_nt_headers/helix8.fasta 05_nt_headers/helix9.fasta 05_nt_headers/helix10.fasta 05_nt_headers/helix11.fasta > 06_concat/concat.fasta
# Out:
# [INFO] read file: 05_nt_headers/helix1.fasta
# [INFO] 1899 records loaded from file: 05_nt_headers/helix1.fasta
# [INFO] read file: 05_nt_headers/helix2.fasta
# [INFO] 1896 records loaded from file: 05_nt_headers/helix2.fasta
# [INFO] read file: 05_nt_headers/helix3.fasta
# [INFO] 1897 records loaded from file: 05_nt_headers/helix3.fasta
# [INFO] read file: 05_nt_headers/helix4.fasta
# [INFO] 1897 records loaded from file: 05_nt_headers/helix4.fasta
# [INFO] read file: 05_nt_headers/helix5.fasta
# [INFO] 1896 records loaded from file: 05_nt_headers/helix5.fasta
# [INFO] read file: 05_nt_headers/helix6.fasta
# [INFO] 1896 records loaded from file: 05_nt_headers/helix6.fasta
# [INFO] read file: 05_nt_headers/helix7.fasta
# [INFO] 1894 records loaded from file: 05_nt_headers/helix7.fasta
# [INFO] read file: 05_nt_headers/helix8.fasta
# [INFO] 1895 records loaded from file: 05_nt_headers/helix8.fasta
# [INFO] read file: 05_nt_headers/helix9.fasta
# ...

# %%
# !seqkit rmdup -s 06_concat/concat.fasta > 06_concat/concatrmdup.fasta
# Out:
# [INFO] 2335601 duplicated records removed
