# %%
from pathlib import Path

from tqdm.notebook import tqdm

# %%
with Path("untitled1.txt").open() as ifh:
    tolnames = [_.strip() for _ in ifh.readlines()]

# %%
# !head new_taxdump/rankedlineage.dmp
# Out:
# 1	|	root	|		|		|		|		|		|		|		|		|
# 131567	|	cellular organisms	|		|		|		|		|		|		|		|		|
# 2157	|	Archaea	|		|		|		|		|		|		|		|		|
# 1935183	|	Asgard group	|		|		|		|		|		|		|		|	Archaea	|
# 2798909	|	Candidatus Baldrarchaeota	|		|		|		|		|		|		|		|	Archaea	|
# 2798916	|	Candidatus Baldrarchaeia	|		|		|		|		|		|	Candidatus Baldrarchaeota	|		|	Archaea	|
# 2798922	|	Candidatus Baldrarchaeales	|		|		|		|		|	Candidatus Baldrarchaeia	|	Candidatus Baldrarchaeota	|		|	Archaea	|
# 2798928	|	Candidatus Baldrarchaeaceae	|		|		|		|	Candidatus Baldrarchaeales	|	Candidatus Baldrarchaeia	|	Candidatus Baldrarchaeota	|		|	Archaea	|
# 2798934	|	Candidatus Baldrarchaeum	|		|		|	Candidatus Baldrarchaeaceae	|	Candidatus Baldrarchaeales	|	Candidatus Baldrarchaeia	|	Candidatus Baldrarchaeota	|		|	Archaea	|
# 2798940	|	Candidatus Baldrarchaeum yapensis	|		|	Candidatus Baldrarchaeum	|	Candidatus Baldrarchaeaceae	|	Candidatus Baldrarchaeales	|	Candidatus Baldrarchaeia	|	Candidatus Baldrarchaeota	|		|	Archaea	|

# %%
def is_excluded(str):
    """Return True if we should exclude this record"""
    exclude_list = ["Candidatus", "sp.", "unclassified", "samples",
                    "unidentified", "uncultured", "symbiont", " x ",
                    "cf.", "-like"]
    for _ in exclude_list:
        if _ in str:
            return True
    return False

genus_species = []

with Path("new_taxdump/rankedlineage.dmp").open() as ifh:
    for line in (_.strip() for _ in ifh.readlines()):
        parts = [_.strip() for _ in line.split("|")]
        if len(parts[2]) == 0 and len(parts[3]):  # no species, but genus exists -> candidate Genus/species pair
            if not is_excluded(parts[1]) and len(parts[1].split()) == 2:
                genus_species.append(parts[1])

# %%
len(genus_species)
# Out:
# 553346

# %%
genus_species[1000:2000]
# Out:
# ['Helicobacter cinaedi',
#  'Helicobacter colisuis',
#  'Helicobacter cynogastricus',
#  'Helicobacter delphinicola',
#  'Helicobacter didelphidarum',
#  'Helicobacter enhydrae',
#  'Helicobacter equorum',
#  'Helicobacter felis',
#  'Helicobacter fennelliae',
#  'Helicobacter ganmani',
#  'Helicobacter heilmannii',
#  'Helicobacter hepaticus',
#  'Helicobacter himalayensis',
#  'Helicobacter jaachi',
#  'Helicobacter japonicus',
#  'Helicobacter kayseriensis',
#  'Helicobacter kumamotonensis',
#  'Helicobacter labacensis',
#  'Helicobacter labetoulli',
#  'Helicobacter macacae',
#  'Helicobacter magdeburgensis',
#  'Helicobacter marmotae',
#  'Helicobacter mastomyrinus',
#  'Helicobacter mehlei',
#  'Helicobacter mesocricetorum',
#  'Helicobacter monodelphidis',
#  'Helicobacter muricola',
#  'Helicobacter muridarum',
#  'Helicobacter mustelae',
#  'Helicobacter pametensis',
#  'Helicobacter peregrinus',
#  'Helicobacter pullorum',
#  'Helicobacter pylori',
#  'Helicobacter rappini',
#  'Helicobacter rodentium',
#  'Helicobacter saguini',
#  'Helicobacter salomonis',
#  'Helicobacter suis',
#  'Helicobacter suncus',
#  'Helicobacter trogontum',
#  'Helicobacter turcicus',
#  'Helicobacter tursiopsae',
#  'Helicobacter typhlonius',
#  'Helicobacter valdiviensis',
#  'Helicobacter vulpecula',
#  'Helicobacter vulpis',
#  'Helicobacter winghamensis',
#  'Wolinella succinogenes',
#  'Hydrogenimonas thermophila',
#  'Hydrogenimonas urashimensis',
#  'Sulfuricurvum kujiense',
#  'Sulfurimonas aquatica',
#  'Sulfurimonas autotrophica',
#  'Sulfurimonas crateris',
#  'Sulfurimonas denitrificans',
#  'Sulfurimonas gotlandica',
#  'Sulfurimonas hongkongensis',
#  'Sulfurimonas hydrogeniphila',
#  'Sulfurimonas indica',
#  'Sulfurimonas lithotrophica',
#  'Sulfurimonas marina',
#  'Sulfurimonas paralvinellae',
#  'Sulfurimonas sediminis',
#  'Sulfurimonas xiamenensis',
#  'Thiovulum majus',
#  'Sulfurospirillum alkalitolerans',
#  'Sulfurospirillum arcachonense',
#  'Sulfurospirillum arsenophilum',
#  'Sulfurospirillum barnesii',
#  'Sulfurospirillum carboxydovorans',
#  'Sulfurospirillum cavolei',
#  'Sulfurospirillum deleyianum',
#  'Sulfurospirillum diekertiae',
#  'Sulfurospirillum halorespirans',
#  'Sulfurospirillum multivorans',
#  'Sulfurospirillum oryzae',
#  'Sulfurospirillum tamanensis',
#  'Nitratifractor salsuginis',
#  'Sulfurovum aggregans',
#  'Sulfurovum denitrificans',
#  'Sulfurovum indicum',
#  'Sulfurovum lithotrophicum',
#  'Sulfurovum riftiae',
#  'Thiofractor thiocaminus',
#  'Caminibacter hydrogeniphilus',
#  'Caminibacter mediatlanticus',
#  'Caminibacter pacificus',
#  'Caminibacter profundus',
#  'Lebetimonas acidiphila',
#  'Lebetimonas natsushimae',
#  'Nautilia abyssi',
#  'Nautilia lithotrophica',
#  'Nautilia nitratireducens',
#  'Nautilia profundicola',
#  'Nitratiruptor tergarcus',
#  'Nitrosophilus alvini',
#  'Nitrosophilus kaiyonis',
#  'Nitrosophilus labii',
#  'Thioreductor micantisoli',
#  'Chrysiogenes arsenatis',
#  'Desulfurispira natronophila',
#  'Desulfurispirillum alkaliphilum',
#  'Desulfurispirillum indicum',
#  'Coprothermobacter platensis',
#  'Coprothermobacter proteolyticus',
#  'Calditerrivibrio nitroreducens',
#  'Deferribacter abyssi',
#  'Deferribacter autotrophicus',
#  'Deferribacter desulfuricans',
#  'Deferribacter thermophilus',
#  'Deferrivibrio essentukiensis',
#  'Flexistipes sinusarabici',
#  'Denitrovibrio acetiphilus',
#  'Geovibrio ferrireducens',
#  'Geovibrio thiophilus',
#  'Limisalsivibrio acetivorans',
#  'Seleniivibrio woodruffii',
#  'Mucispirillum schaedleri',
#  'Petrothermobacter organivorans',
#  'Bradymonas sediminis',
#  'Persicimonas caeni',
#  'Lujinxingia litoralis',
#  'Lujinxingia sediminis',
#  'Lujinxingia vulgaris',
#  'Microvenator marinus',
#  'Algidimarina propionica',
#  'Dissulfurimicrobium hydrothermale',
#  'Dissulfurirhabdus thermomarina',
#  'Dictyoglomus thermophilum',
#  'Dictyoglomus turgidum',
#  'Elusimicrobium minutum',
#  'Endomicrobium proavitum',
#  'Acetofilamentum rigidum',
#  'Acetothermus paucivorans',
#  'Bacteroides acidifaciens',
#  'Bacteroides bouchesdurhonensis',
#  'Bacteroides caccae',
#  'Bacteroides caecicola',
#  'Bacteroides caecigallinarum',
#  'Bacteroides caecimuris',
#  'Bacteroides cellulolyticus',
#  'Bacteroides cellulosilyticus',
#  'Bacteroides clarus',
#  'Bacteroides congonensis',
#  'Bacteroides coprosuis',
#  'Bacteroides cutis',
#  'Bacteroides denticanum',
#  'Bacteroides difficilis',
#  'Bacteroides eggerthii',
#  'Bacteroides facilis',
#  'Bacteroides faecalis',
#  'Bacteroides faecichinchillae',
#  'Bacteroides faecis',
#  'Bacteroides faecium',
#  'Bacteroides finegoldii',
#  'Bacteroides fluxus',
#  'Bacteroides fragilis',
#  'Bacteroides galacturonicus',
#  'Bacteroides gallinaceum',
#  'Bacteroides gallinarum',
#  'Bacteroides graminisolvens',
#  'Bacteroides helcogenes',
#  'Bacteroides heparinolyticus',
#  'Bacteroides hominis',
#  'Bacteroides humanifaecis',
#  'Bacteroides ihuae',
#  'Bacteroides ilei',
#  'Bacteroides intestinalis',
#  'Bacteroides koreensis',
#  'Bacteroides kribbi',
#  'Bacteroides luhongzhouii',
#  'Bacteroides luti',
#  'Bacteroides mediterraneensis',
#  'Bacteroides multiformis',
#  'Bacteroides ndongoniae',
#  'Bacteroides neonati',
#  'Bacteroides nordii',
#  'Bacteroides oleiciplenus',
#  'Bacteroides ovatus',
#  'Bacteroides parvus',
#  'Bacteroides propionicifaciens',
#  'Bacteroides propionicigenes',
#  'Bacteroides pyogenes',
#  'Bacteroides reticulotermitis',
#  'Bacteroides rhinocerotis',
#  'Bacteroides rodentium',
#  'Bacteroides salyersiae',
#  'Bacteroides sedimenti',
#  'Bacteroides stercorirosoris',
#  'Bacteroides stercoris',
#  'Bacteroides thetaiotaomicron',
#  'Bacteroides timonensis',
#  'Bacteroides togonis',
#  'Bacteroides uniformis',
#  'Bacteroides xylanisolvens',
#  'Bacteroides zhangwenhongii',
#  'Bacteroides zoogleoformans',
#  'Caecibacteroides pullorum',
#  'Mediterranea massiliensis',
#  'Paraphocaeicola brunensis',
#  'Phocaeicola abscessus',
#  'Phocaeicola barnesiae',
#  'Phocaeicola coprocola',
#  'Phocaeicola coprophilus',
#  'Phocaeicola dorei',
#  'Phocaeicola faecalis',
#  'Phocaeicola faecicola',
#  'Phocaeicola faecium',
#  'Phocaeicola fibrisolvens',
#  'Phocaeicola intestinalis',
#  'Phocaeicola massiliensis',
#  'Phocaeicola oris',
#  'Phocaeicola paurosaccharolyticus',
#  'Phocaeicola plebeius',
#  'Phocaeicola salanitronis',
#  'Phocaeicola sartorii',
#  'Phocaeicola vulgatus',
#  'Balneicella halophila',
#  'Barnesiella faecis',
#  'Barnesiella intestinihominis',
#  'Barnesiella propionica',
#  'Barnesiella viscericola',
#  'Coprobacter fastidiosus',
#  'Coprobacter secundus',
#  'Coprobacter tertius',
#  'Dysgonomonas alginatilytica',
#  'Dysgonomonas capnocytophagoides',
#  'Dysgonomonas gadei',
#  'Dysgonomonas hofstadii',
#  'Dysgonomonas macrotermitis',
#  'Dysgonomonas massiliensis',
#  'Dysgonomonas mossii',
#  'Dysgonomonas oryzarvi',
#  'Dysgonomonas termitidis',
#  'Dysgonomonas wimpennyi',
#  'Fermentimonas caenicola',
#  'Petrimonas mucosa',
#  'Petrimonas sulfuriphila',
#  'Proteiniphilum acetatigenes',
#  'Proteiniphilum propionicum',
#  'Proteiniphilum saccharofermentans',
#  'Seramator thermalis',
#  'Lentimicrobium saccharophilum',
#  'Duncaniella dubosii',
#  'Duncaniella freteri',
#  'Duncaniella muricolitica',
#  'Duncaniella muris',
#  'Heminiphilus faecis',
#  'Lepagella muris',
#  'Muribaculum caecicola',
#  'Muribaculum gordoncarteri',
#  'Muribaculum intestinale',
#  'Paramuribaculum intestinale',
#  'Sangeribacter muris',
#  'Sodaliphilus pleomorphus',
#  'Butyricimonas faecalis',
#  'Butyricimonas faecihominis',
#  'Butyricimonas hominis',
#  'Butyricimonas paravirosa',
#  'Butyricimonas phoceensis',
#  'Butyricimonas synergistica',
#  'Butyricimonas vaginalis',
#  'Butyricimonas virosa',
#  'Culturomica massiliensis',
#  'Odoribacter denticanis',
#  'Odoribacter laneus',
#  'Odoribacter lunatus',
#  'Odoribacter splanchnicus',
#  'Paludibacter jiangxiensis',
#  'Paludibacter propionicigenes',
#  'Falsiporphyromonas endometrii',
#  'Gabonia massiliensis',
#  'Gabonibacter massiliensis',
#  'Gabonibacter timonensis',
#  'Lascolabacillus massiliensis',
#  'Macellibacteroides fermentans',
#  'Massilibacteroides vaginae',
#  'Microbacter margulisiae',
#  'Porphyromonas asaccharolytica',
#  'Porphyromonas bennonis',
#  'Porphyromonas bobii',
#  'Porphyromonas cangingivalis',
#  'Porphyromonas canis',
#  'Porphyromonas canoris',
#  'Porphyromonas catoniae',
#  'Porphyromonas circumdentaria',
#  'Porphyromonas crevioricanis',
#  'Porphyromonas endodontalis',
#  'Porphyromonas gingivalis',
#  'Porphyromonas gingivicanis',
#  'Porphyromonas gulae',
#  'Porphyromonas katsikii',
#  'Porphyromonas levii',
#  'Porphyromonas loveana',
#  'Porphyromonas macacae',
#  'Porphyromonas pasteri',
#  'Porphyromonas pogonae',
#  'Porphyromonas somerae',
#  'Porphyromonas uenonis',
#  'Sanguibacteroides justesenii',
#  'Alloprevotella rava',
#  'Alloprevotella tannerae',
#  'Hallella absiana',
#  'Hallella bergensis',
#  'Hallella colorans',
#  'Hallella faecis',
#  'Hallella mizrahii',
#  'Hallella multisaccharivorax',
#  'Hallella seregens',
#  'Hoylesella buccalis',
#  'Hoylesella enoeca',
#  'Hoylesella loescheii',
#  'Hoylesella marshii',
#  'Hoylesella nanceiensis',
#  'Hoylesella oralis',
#  'Hoylesella pleuritidis',
#  'Hoylesella saccharolytica',
#  'Hoylesella shahii',
#  'Hoylesella timonensis',
#  'Marseilla massiliensis',
#  'Massiliprevotella massiliensis',
#  'Metaprevotella massiliensis',
#  'Palleniella intestinalis',
#  'Palleniella muris',
#  'Paraprevotella clara',
#  'Paraprevotella xylaniphila',
#  'Prevotella albensis',
#  'Prevotella amnii',
#  'Prevotella aurantiaca',
#  'Prevotella baroniae',
#  'Prevotella bivia',
#  'Prevotella brevis',
#  'Prevotella brunnea',
#  'Prevotella bryantii',
#  'Prevotella buccae',
#  'Prevotella cerevisiae',
#  'Prevotella communis',
#  'Prevotella conceptionensis',
#  'Prevotella corporis',
#  'Prevotella dentalis',
#  'Prevotella dentasini',
#  'Prevotella denticola',
#  'Prevotella disiens',
#  'Prevotella falsenii',
#  'Prevotella fusca',
#  'Prevotella herbatica',
#  'Prevotella histicola',
#  'Prevotella hominis',
#  'Prevotella ihumii',
#  'Prevotella illustrans',
#  'Prevotella intermedia',
#  'Prevotella jejuni',
#  'Prevotella koreensis',
#  'Prevotella lacticifex',
#  'Prevotella lascolaii',
#  'Prevotella maculosa',
#  'Prevotella marseillensis',
#  'Prevotella massiliensis',
#  'Prevotella melaninogenica',
#  'Prevotella micans',
#  'Prevotella multiformis',
#  'Prevotella nigrescens',
#  'Prevotella oris',
#  'Prevotella oryzae',
#  'Prevotella oulorum',
#  'Prevotella pallens',
#  'Prevotella paludivivens',
#  'Prevotella pectinovora',
#  'Prevotella phocaeensis',
#  'Prevotella rara',
#  'Prevotella ruminicola',
#  'Prevotella salivae',
#  'Prevotella scopos',
#  'Prevotella stercorea',
#  'Prevotella veroralis',
#  'Prevotella vespertina',
#  'Xylanibacter caecicola',
#  'Xylanibacter muris',
#  'Xylanibacter rodentium',
#  'Prevotellamassilia timonensis',
#  'Pseudoprevotella muciniphila',
#  'Segatella copri',
#  'Acetobacteroides hydrogenigenes',
#  'Alistipes communis',
#  'Alistipes dispar',
#  'Alistipes finegoldii',
#  'Alistipes hominis',
#  'Alistipes ihumii',
#  'Alistipes indistinctus',
#  'Alistipes inops',
#  'Alistipes massiliensis',
#  'Alistipes megaguti',
#  'Alistipes montrealensis',
#  'Alistipes muris',
#  'Alistipes okayasuensis',
#  'Alistipes onderdonkii',
#  'Alistipes provencensis',
#  'Alistipes putredinis',
#  'Alistipes senegalensis',
#  'Alistipes shahii',
#  'Alistipes timonensis',
#  'Anaerocella delicata',
#  'Gallalistipes aquisgranensis',
#  'Millionella massiliensis',
#  'Mucinivorans hirudinis',
#  'Rikenella microfusus',
#  'Ruminofilibacter xylanolyticum',
#  'Tidjanibacter massiliensis',
#  'Salinivirga cyanobacteriivorans',
#  'Parabacteroides acidifaciens',
#  'Parabacteroides bouchesdurhonensis',
#  'Parabacteroides chartae',
#  'Parabacteroides chinchillae',
#  'Parabacteroides chongii',
#  'Parabacteroides distasonis',
#  'Parabacteroides faecalis',
#  'Parabacteroides faecis',
#  'Parabacteroides goldsteinii',
#  'Parabacteroides gordonii',
#  'Parabacteroides hominis',
#  'Parabacteroides johnsonii',
#  'Parabacteroides massiliensis',
#  'Parabacteroides merdae',
#  'Parabacteroides pacaensis',
#  'Parabacteroides pekinense',
#  'Parabacteroides provencensis',
#  'Parabacteroides segnis',
#  'Parabacteroides timonensis',
#  'Tannerella forsythia',
#  'Tannerella pachnodae',
#  'Tannerella serpentiformis',
#  'Perlabentimonas gracilis',
#  'Tenuifilum thalassicum',
#  'Williamwhitmania taraxaci',
#  'Ancylomarina euxinus',
#  'Ancylomarina longa',
#  'Ancylomarina psychrotolerans',
#  'Ancylomarina salipaludis',
#  'Ancylomarina subtilis',
#  'Labilibaculum antarcticum',
#  'Labilibaculum euxinus',
#  'Labilibaculum filiforme',
#  'Labilibaculum manganireducens',
#  'Marinifilum albidiflavum',
#  'Marinifilum breve',
#  'Marinifilum caeruleilacunae',
#  'Marinifilum flexuosum',
#  'Marinifilum fragile',
#  'Alkaliflexus imshenetskii',
#  'Alkalitalea saponilacus',
#  'Anaerophaga thermohalophila',
#  'Breznakibacter xylanolyticus',
#  'Carboxylicivirga flava',
#  'Carboxylicivirga linearis',
#  'Carboxylicivirga marina',
#  'Carboxylicivirga mesophila',
#  'Carboxylicivirga sediminis',
#  'Carboxylicivirga taeanensis',
#  'Geofilum rhodophaeum',
#  'Geofilum rubicundum',
#  'Labilibacter marinus',
#  'Labilibacter sediminis',
#  'Mangroviflexus xiamenensis',
#  'Marinilabilia nitratireducens',
#  'Marinilabilia rubra',
#  'Marinilabilia salmonicolor',
#  'Natronoflexus pectinivorans',
#  'Plebeiobacterium marinum',
#  'Plebeiobacterium sediminum',
#  'Saccharicrinis aurantiacus',
#  'Saccharicrinis carchari',
#  'Saccharicrinis fermentans',
#  'Thermophagus xiamenensis',
#  'Aquipluma nitroreducens',
#  'Draconibacterium filum',
#  'Draconibacterium halophilum',
#  'Draconibacterium mangrovi',
#  'Draconibacterium orientale',
#  'Draconibacterium sediminis',
#  'Gaoshiqia sediminis',
#  'Mangrovibacterium diazotrophicum',
#  'Mangrovibacterium lignilyticum',
#  'Mangrovibacterium marinum',
#  'Maribellus comscasis',
#  'Maribellus luteus',
#  'Maribellus maritimus',
#  'Maribellus sediminis',
#  'Mariniphaga anaerophila',
#  'Mariniphaga sediminis',
#  'Meniscus glaucopis',
#  'Prolixibacter bellariivorans',
#  'Prolixibacter denitrificans',
#  'Puteibacter caeruleilacunae',
#  'Roseimarinus sediminis',
#  'Sunxiuqinia dokdonensis',
#  'Sunxiuqinia elliptica',
#  'Sunxiuqinia faeciviva',
#  'Sunxiuqinia indica',
#  'Sunxiuqinia rutila',
#  'Tangfeifania diversioriginum',
#  'Agriterribacter humi',
#  'Agriterribacter soli',
#  'Arachidicoccus ginsenosidivorans',
#  'Arachidicoccus rhizosphaerae',
#  'Arachidicoccus soli',
#  'Arachidicoccus terrestris',
#  'Aridibaculum aurantiacum',
#  'Arvibacter aurantiibacter',
#  'Arvibacter flaviflagrans',
#  'Aurantisolimonas haloimpatiens',
#  'Chitinophaga agri',
#  'Chitinophaga agrisoli',
#  'Chitinophaga alhagiae',
#  'Chitinophaga arvensicola',
#  'Chitinophaga aurantiaca',
#  'Chitinophaga barathri',
#  'Chitinophaga caeni',
#  'Chitinophaga caseinilytica',
#  'Chitinophaga chungangae',
#  'Chitinophaga costaii',
#  'Chitinophaga cymbidii',
#  'Chitinophaga deserti',
#  'Chitinophaga dinghuensis',
#  'Chitinophaga eiseniae',
#  'Chitinophaga filiformis',
#  'Chitinophaga flava',
#  'Chitinophaga fulva',
#  'Chitinophaga ginsengihumi',
#  'Chitinophaga ginsengisegetis',
#  'Chitinophaga ginsengisoli',
#  'Chitinophaga horti',
#  'Chitinophaga hostae',
#  'Chitinophaga humicola',
#  'Chitinophaga japonensis',
#  'Chitinophaga jiangningensis',
#  'Chitinophaga longshanensis',
#  'Chitinophaga lutea',
#  'Chitinophaga niabensis',
#  'Chitinophaga niastensis',
#  'Chitinophaga oryzae',
#  'Chitinophaga oryziterrae',
#  'Chitinophaga parva',
#  'Chitinophaga pinensis',
#  'Chitinophaga polysaccharea',
#  'Chitinophaga qingshengii',
#  'Chitinophaga rhizophila',
#  'Chitinophaga rhizosphaerae',
#  'Chitinophaga rupis',
#  'Chitinophaga salinisoli',
#  'Chitinophaga sancti',
#  'Chitinophaga sedimenti',
#  'Chitinophaga silvatica',
#  'Chitinophaga silvisoli',
#  'Chitinophaga skermanii',
#  'Chitinophaga soli',
#  'Chitinophaga solisilvae',
#  'Chitinophaga taiwanensis',
#  'Chitinophaga tropicalis',
#  'Chitinophaga varians',
#  'Chitinophaga vietnamensis',
#  'Cnuella takakiae',
#  'Compostibacter hankyongensis',
#  'Deminuibacter soli',
#  'Dinghuibacter silviterrae',
#  'Edaphobaculum flavum',
#  'Edaphocola aurantiacus',
#  'Edaphocola flava',
#  'Ferruginibacter albus',
#  'Ferruginibacter alkalilentus',
#  'Ferruginibacter lapsinanis',
#  'Ferruginibacter paludis',
#  'Ferruginibacter profundus',
#  'Ferruginibacter yonginensis',
#  'Filimonas aquilariae',
#  'Filimonas effusa',
#  'Filimonas endophytica',
#  'Filimonas lacunae',
#  'Filimonas zeae',
#  'Flaviaesturariibacter amylovorans',
#  'Flaviaesturariibacter aridisoli',
#  'Flaviaesturariibacter flavus',
#  'Flaviaesturariibacter luteus',
#  'Flaviaesturariibacter terrae',
#  'Flavihumibacter cheonanensis',
#  'Flavihumibacter fluminis',
#  'Flavihumibacter fluvii',
#  'Flavihumibacter petaseus',
#  'Flavihumibacter profundi',
#  'Flavihumibacter rivuli',
#  'Flavihumibacter sediminis',
#  'Flavihumibacter soli',
#  'Flavihumibacter solisilvae',
#  'Flavihumibacter stibioxidans',
#  'Flavipsychrobacter stenotrophus',
#  'Flavisolibacter aluminii',
#  'Flavisolibacter carri',
#  'Flavisolibacter galbus',
#  'Flavisolibacter ginsengisoli',
#  'Flavisolibacter ginsengiterrae',
#  'Flavisolibacter ginsenosidimutans',
#  'Flavisolibacter longurius',
#  'Flavisolibacter metallilatus',
#  'Flavisolibacter nicotianae',
#  'Flavisolibacter rigui',
#  'Flavisolibacter swuensis',
#  'Flavisolibacter tropicus',
#  'Flavitalea antarctica',
#  'Flavitalea flava',
#  'Flavitalea gansuensis',
#  'Flavitalea populi',
#  'Foetidibacter luteolus',
#  'Ginsengibacter hankyongi',
#  'Gynurincola endophyticus',
#  'Hanamia caeni',
#  'Haoranjiania flava',
#  'Heliimonas saccharivorans',
#  'Hydrobacter penzbergensis',
#  'Hydrotalea flava',
#  'Hydrotalea lipotrueae',
#  'Hydrotalea sandarakina',
#  'Ilyomonas limi',
#  'Lacibacter cauensis',
#  'Lacibacter daechungensis',
#  'Lacibacter luteus',
#  'Lacibacter nakdongensis',
#  'Limnovirga soli',
#  'Longitalea arenae',
#  'Longitalea luteola',
#  'Mucibacter soli',
#  'Nemorincola caseinilytica',
#  'Niabella agricola',
#  'Niabella aquatica',
#  'Niabella aurantiaca',
#  'Niabella beijingensis',
#  'Niabella drilacis',
#  'Niabella ginsengisoli',
#  'Niabella ginsenosidivorans',
#  'Niabella hibiscisoli',
#  'Niabella hirudinis',
#  'Niabella pedocola',
#  'Niabella soli',
#  'Niabella terrae',
#  'Niabella thaonhiensis',
#  'Niabella tibetensis',
#  'Niabella yanshanensis',
#  'Niastella caeni',
#  'Niastella gongjuensis',
#  'Niastella hibisci',
#  'Niastella koreensis',
#  'Niastella populi',
#  'Niastella soli',
#  'Niastella vici',
#  'Niastella yeongjuensis',
#  'Niveitalea solisilvae',
#  'Panacibacter ginsenosidivorans',
#  'Panacibacter microcysteis',
#  'Paracnuella aquatica',
#  'Parafilimonas rhizosphaerae',
#  'Parafilimonas terrae',
#  'Paraflavisolibacter caeni',
#  'Paraflavitalea devenefica',
#  'Paraflavitalea soli',
#  'Parasediminibacterium paludis',
#  'Parasegetibacter luojiensis',
#  'Parasegetibacter terrae',
#  'Phnomibacter ginsenosidimutans',
#  'Pinibacter aurantiacus',
#  'Pseudobacter ginsenosidimutans',
#  'Pseudocnuella soli',
#  'Pseudoflavitalea muciniphila',
#  'Pseudoflavitalea rhizosphaerae',
#  'Pseudoflavitalea soli',
#  'Puia dinghuensis',
#  'Rurimicrobium arvi',
#  'Sediminibacterium aquarii',
#  'Sediminibacterium ginsengisoli',
#  'Sediminibacterium goheungense',
#  'Sediminibacterium lactis',
#  'Sediminibacterium magnilacihabitans',
#  'Sediminibacterium roseum',
#  'Sediminibacterium salmoneum',
#  'Sediminibacterium soli',
#  'Segetibacter aerophilus',
#  'Segetibacter koreensis',
#  'Taibaiella chishuiensis',
#  'Taibaiella coffeisoli',
#  'Taibaiella helva',
#  'Taibaiella koreensis',
#  'Taibaiella lutea',
#  'Taibaiella smilacinae',
#  'Taibaiella soli',
#  'Taibaiella yonginensis',
#  'Terrimonas aquatica',
#  'Terrimonas arctica',
#  'Terrimonas crocea',
#  'Terrimonas ferruginea',
#  'Terrimonas ginsenosidimutans',
#  'Terrimonas lutea',
#  'Terrimonas pekingensis',
#  'Terrimonas rhizosphaerae',
#  'Terrimonas rubra',
#  'Terrimonas soli',
#  'Terrimonas suqianensis',
#  'Terrimonas terrae',
#  'Thermoflavifilum aggregans',
#  'Thermoflavifilum thermophilum',
#  'Bernardetia litoralis',
#  'Garritya polymorpha',
#  'Hugenholtzia roseola',
#  'Catalinimonas alkaloidigena',
#  'Catalinimonas niigatensis',
#  'Porifericola rhodea',
#  'Tunicatimonas pelagia',
#  'Cesiribacter andamanensis',
#  'Cesiribacter roseus',
#  'Nafulsella turpanensis',
#  'Algoriphagus aestuarii',
#  'Algoriphagus aestuariicola',
#  'Algoriphagus algorifonticola',
#  'Algoriphagus alkaliphilus',
#  'Algoriphagus antarcticus',
#  'Algoriphagus aquaeductus',
#  'Algoriphagus aquaemixtae',
#  'Algoriphagus aquatilis',
#  'Algoriphagus aquimarinus',
#  'Algoriphagus aquimaris',
#  'Algoriphagus boritolerans',
#  'Algoriphagus boseongensis',
#  'Algoriphagus chordae',
#  'Algoriphagus chungangensis',
#  'Algoriphagus confluentis',
#  'Algoriphagus faecimaris',
#  'Algoriphagus formosus',
#  'Algoriphagus halophilus',
#  'Algoriphagus hitonicola',
#  'Algoriphagus iocasae',
#  'Algoriphagus jejuensis',
#  'Algoriphagus kandeliae',
#  'Algoriphagus lacus',
#  'Algoriphagus limi',
#  'Algoriphagus litoralis',
#  'Algoriphagus litorisediminis',
#  'Algoriphagus locisalis',
#  'Algoriphagus lutimaris',
#  'Algoriphagus machipongonensis',
#  'Algoriphagus mannitolivorans',
#  'Algoriphagus marincola',
#  'Algoriphagus marinus',
#  'Algoriphagus marisflavi',
#  'Algoriphagus namhaensis',
#  'Algoriphagus olei',
#  'Algoriphagus oliviformis',
#  'Algoriphagus ornithinivorans',
#  'Algoriphagus pacificus',
#  'Algoriphagus ratkowskyi',
#  'Algoriphagus resistens',
#  'Algoriphagus roseus',
#  'Algoriphagus sanaruensis',
#  'Algoriphagus shivajiensis',
#  'Algoriphagus taeanensis',
#  'Algoriphagus taiwanensis',
#  'Algoriphagus terrigena',
#  'Algoriphagus trabzonensis',
#  'Algoriphagus vanfongensis',
#  'Algoriphagus winogradskyi',
#  'Algoriphagus yeomjeoni',
#  'Algoriphagus zhangzhouensis',
#  'Aquiflexum balticum',
#  'Aquiflexum gelatinilyticum',
#  'Aquiflexum lacus',
#  'Arthrospiribacter ruber',
#  'Belliella alkalica',
#  'Belliella aquatica',
#  'Belliella baltica',
#  'Belliella buryatensis',
#  'Belliella calami',
#  'Belliella filtrata',
#  'Belliella kenyensis',
#  'Belliella marina',
#  'Belliella pelovolcani',
#  'Cecembia calidifontis',
#  'Cecembia lonarensis',
#  'Cecembia rubra',
#  'Cognataquiflexum aquatile',
#  'Cognataquiflexum nitidum',
#  'Cognataquiflexum rubidum',
#  'Cyclobacterium amurskyense',
#  'Cyclobacterium caenipelagi',
#  'Cyclobacterium jeungdonense',
#  'Cyclobacterium lianum',
#  'Cyclobacterium marinum',
#  'Cyclobacterium plantarum',
#  'Cyclobacterium qasimii',
#  'Cyclobacterium roseum',
#  'Cyclobacterium salsum',
#  'Cyclobacterium sediminis',
#  'Cyclobacterium xiamenense',
#  'Echinicola arenosa',
#  'Echinicola jeungdonensis',
#  'Echinicola marina',
#  'Echinicola pacifica',
#  'Echinicola rosea',
#  'Echinicola salinicaeni',
#  'Echinicola sediminis',
#  'Echinicola shivajiensis',
#  'Echinicola soli',
#  'Echinicola strongylocentroti',
#  'Echinicola vietnamensis',
#  'Fontibacter ferrireducens',
#  'Fontibacter flavus',
#  'Indibacter alkaliphilus',
#  'Litoribacter alkaliphilus',
#  'Litoribacter populi',
#  'Litoribacter ruber',
#  'Lunatibacter salilacus',
#  'Lunatimonas lonarensis',
#  'Lunatimonas salinarum',
#  'Mariniradius saccharolyticus',
#  'Mongoliibacter ruber',
#  'Mongoliicoccus alkaliphilus',
#  'Mongoliicoccus roseus',
#  'Mongoliitalea daihaiensis',
#  'Mongoliitalea lutea',
#  'Negadavirga shengliensis',
#  'Nitritalea halalkaliphila',
#  'Pararhodonellum marinum',
#  'Penaeicola halotolerans',
#  'Pleomorphovibrio marinus',
#  'Shivajiella indica',
#  'Anditalea andensis',
#  'Aquirufa antheringensis',
#  'Aquirufa aurantiipilula',
#  'Aquirufa beregesia',
#  'Aquirufa ecclesiirivi',
#  'Aquirufa lenticrescens',
#  'Aquirufa nivalisilvae',
#  'Aquirufa rosea',
#  'Arundinibacter roseus',
#  'Chryseosolibacter histidini',
#  'Chryseosolibacter indicus',
#  'Chryseotalea sanaruensis',
#  'Cytophaga allerginae',
#  'Cytophaga aurantiaca',
#  'Cytophaga hutchinsonii',
#  'Dawidia cretensis',
#  'Dawidia soli',
#  'Edaphorhabdus rosea',
#  'Rhabdobacter roseus',
#  'Rhodocytophaga aerolata',
#  'Rhodocytophaga rosea',
#  'Rhodonellum ikkaensis',
#  'Rhodonellum psychrophilum',
#  'Rudanella lutea',
#  'Rudanella paleaurantiibacter',
#  'Sandaracinomonas limnophila',
#  'Siphonobacter aquaeclarae',
#  'Siphonobacter curvatus',
#  'Siphonobacter intestinalis',
#  'Spirosoma aerolatum',
#  'Spirosoma aerophilum',
#  'Spirosoma agri',
#  'Spirosoma arboris',
#  'Spirosoma arcticum',
#  'Spirosoma areae',
#  'Spirosoma aureum',
#  'Spirosoma carri',
#  'Spirosoma daeguense',
#  'Spirosoma endbachense',
#  'Spirosoma endophyticum',
#  'Spirosoma escalantus',
#  'Spirosoma flavum',
#  'Spirosoma flavus',
#  'Spirosoma fluminis',
#  'Spirosoma fluviale',
#  'Spirosoma gilvum',
#  'Spirosoma harenae',
#  'Spirosoma horti',
#  'Spirosoma humi',
#  'Spirosoma jeollabukense',
#  'Spirosoma knui',
#  'Spirosoma koreense',
#  'Spirosoma lacussanchae',
#  'Spirosoma linguale',
#  'Spirosoma liriopis',
#  'Spirosoma litoris',
#  'Spirosoma lituiforme',
#  'Spirosoma luteolum',
#  'Spirosoma luteum',
#  'Spirosoma metallicum',
#  'Spirosoma metallilatum',
#  'Spirosoma metallum',
#  'Spirosoma migulaei',
#  'Spirosoma montaniterrae',
#  'Spirosoma navajo',
#  'Spirosoma oryzae',
#  'Spirosoma oryzicola',
#  'Spirosoma panaciterrae',
#  'Spirosoma pollinicola',
#  'Spirosoma pomorum',
#  'Spirosoma profusum',
#  'Spirosoma pulveris',
#  'Spirosoma radiotolerans',
#  'Spirosoma rhododendri',
#  'Spirosoma rigui',
#  'Spirosoma soli',
#  'Spirosoma sordidisoli',
#  'Spirosoma spitsbergense',
#  'Spirosoma swuense',
#  'Spirosoma taeanense',
#  'Spirosoma telluris',
#  'Spirosoma terrae',
#  'Spirosoma utsteinense',
#  'Spirosoma validum',
#  'Sporocytophaga cauliformis',
#  'Sporocytophaga myxococcoides',
#  'Tellurirhabdus rosea',
#  'Algivirga pacifica',
#  'Chondrinema litorale',
#  'Flammeovirga agarivorans',
#  'Flammeovirga aprica',
#  'Flammeovirga arenaria',
#  'Flammeovirga kamogawensis',
#  'Flammeovirga pacifica',
#  'Flammeovirga pectinis',
#  'Flammeovirga yaeyamensis',
#  'Flexithrix dorotheae',
#  'Imperialibacter roseus',
#  'Limibacter armeniacum',
#  'Marinigracilibium pacificum',
#  'Perexilibacter aurantiacus',
#  'Rapidithrix thailandica',
#  'Sediminitomix flava',
#  'Flexibacter echinicida',
#  'Flexibacter flexilis',
#  'Chryseolinea lacunae',
#  'Chryseolinea serpens',
#  'Chryseolinea soli',
#  'Fulvivirga aurantia',
#  'Fulvivirga imtechensis',
#  'Fulvivirga kasyanovii',
#  'Fulvivirga lutea',
#  'Fulvivirga lutimaris',
#  'Fulvivirga marina',
#  'Fulvivirga sedimenti',
#  'Fulvivirga sediminis',
#  'Ohtaekwangia koreensis',
#  'Ohtaekwangia kribbensis',
#  'Parachryseolinea silvisoli',
#  'Pseudochryseolinea flava',
#  'Xanthovirga aplysinae',
#  'Adhaeribacter aerolatus',
#  'Adhaeribacter aerophilus',
#  'Adhaeribacter aquaticus',
#  'Adhaeribacter arboris',
#  'Adhaeribacter pallidiroseus',
#  'Adhaeribacter radiodurans',
#  'Adhaeribacter rhizoryzae',
#  'Adhaeribacter soli',
#  'Adhaeribacter swui',
#  'Adhaeribacter terrae',
#  'Adhaeribacter terreus',
#  'Adhaeribacter terrigena',
#  'Botryobacter ruber',
#  'Hymenobacter actinosclerus',
#  'Hymenobacter aerophilus',
#  'Hymenobacter agri',
#  'Hymenobacter algoricola',
#  'Hymenobacter amundsenii',
#  'Hymenobacter aquaticus',
#  'Hymenobacter aquatilis',
#  'Hymenobacter arcticus',
#  'Hymenobacter armeniacus',
#  'Hymenobacter artigasi',
#  'Hymenobacter baengnokdamensis',
#  'Hymenobacter bucti',
#  'Hymenobacter busanensis',
#  'Hymenobacter caeli',
#  'Hymenobacter canadensis',
#  'Hymenobacter cavernae',
#  'Hymenobacter chitinivorans',
#  'Hymenobacter citatus',
#  'Hymenobacter coalescens',
#  'Hymenobacter coccineus',
#  'Hymenobacter crusticola',
#  'Hymenobacter cyanobacteriorum',
#  'Hymenobacter daecheongensis',
#  'Hymenobacter daeguensis',
#  'Hymenobacter daejeonensis',
#  'Hymenobacter defluvii',
#  'Hymenobacter duratus',
#  'Hymenobacter edaphi',
#  'Hymenobacter elongatus',
#  'Hymenobacter fastidiosus',
#  'Hymenobacter fodinae',
#  'Hymenobacter frigidus',
#  'Hymenobacter gelipurpurascens',
#  'Hymenobacter ginkgonis',
#  'Hymenobacter glacialis',
#  'Hymenobacter glacieicola',
#  'Hymenobacter gummosus']

# %%
matched_names = []

for name in tqdm(genus_species):
    testname = name.replace(" ", "_")
    for tolname in tolnames:
        if testname in tolname:
            matched_names.append(testname)

len(matched_names)
# Out:
#   0%|          | 0/553346 [00:00<?, ?it/s]
# 1203

# %%
sorted(matched_names)[:100]
# Out:
# ['Abiotrophia_defectiva',
#  'Acanthamoeba_castellanii',
#  'Acaricomes_phytoseiuli',
#  'Acaryochloris_marina',
#  'Acetivibrio_cellulolyticus',
#  'Acetobacter_pasteurianus',
#  'Acetobacterium_woodii',
#  'Acetohalobium_arabaticum',
#  'Acetonema_longum',
#  'Acholeplasma_laidlawii',
#  'Achromobacter_xylosoxidans',
#  'Acidaminobacter_hydrogenoformans',
#  'Acidaminococcus_fermentans',
#  'Acidianus_hospitalis',
#  'Acidilobus_saccharovorans',
#  'Acidimicrobium_ferrooxidans',
#  'Acidiphilium_multivorum',
#  'Acidithiobacillus_ferrivorans',
#  'Acidobacterium_capsulatum',
#  'Acidocella_facilis',
#  'Acidothermus_cellulolyticus',
#  'Acinetobacter_baumannii',
#  'Actibacterium_mucosum',
#  'Actinobacillus_pleuropneumoniae',
#  'Actinokineospora_inagensis',
#  'Actinomadura_madurae',
#  'Actinomyces_naeslundii',
#  'Actinomycetospora_chiangmaiensis',
#  'Actinoplanes_missouriensis',
#  'Actinopolymorpha_alba',
#  'Actinopolyspora_mortivallis',
#  'Actinospica_robiniae',
#  'Actinosynnema_mirum',
#  'Actinotalea_ferrariae',
#  'Acyrthosiphon_pisum',
#  'Acyrthosiphon_pisum',
#  'Acyrthosiphon_pisum',
#  'Adhaeribacter_aquaticus',
#  'Adlercreutzia_equolifaciens',
#  'Aedes_aegypti',
#  'Aequorivita_sublithincola',
#  'Aerococcus_urinae',
#  'Aeromicrobium_marinum',
#  'Aeromonas_hydrophila',
#  'Aeropyrum_camini',
#  'Aestuariibacter_salexigens',
#  'Aestuariimicrobium_kwangyangense',
#  'Afifella_pfennigii',
#  'Agarivorans_albus',
#  'Aggregatibacter_actinomycetemcomitans',
#  'Agrococcus_lahaulensis',
#  'Agromyces_subbeticus',
#  'Ailuropoda_melanoleuca',
#  'Akkermansia_muciniphila',
#  'Alcaligenes_faecalis',
#  'Alcanivorax_borkumensis',
#  'Alexandrium_tamarense',
#  'Algicola_sagamiensis',
#  'Algiphilus_aromaticivorans',
#  'Alicycliphilus_denitrificans',
#  'Alicyclobacillus_acidocaldarius',
#  'Alishewanella_agri',
#  'Alistipes_finegoldii',
#  'Alkalibacillus_haloalkaliphilus',
#  'Alkaliflexus_imshenetskii',
#  'Alkalilimnicola_ehrlichii',
#  'Alkaliphilus_oremlandii',
#  'Alkanindiges_illinoisensis',
#  'Allisonella_histaminiformans',
#  'Allobaculum_stercoricanis',
#  'Allochromatium_vinosum',
#  'Allofustis_seminis',
#  'Alloiococcus_otitis',
#  'Allomyces_macrogynus',
#  'Alloscardovia_omnicolens',
#  'Altererythrobacter_ishigakiensis',
#  'Alteromonas_macleodii',
#  'Alysiella_crassa',
#  'Aminiphilus_circumscriptus',
#  'Aminobacterium_colombiense',
#  'Aminomonas_paucivorans',
#  'Ammonifex_degensii',
#  'Amoebidium_parasiticum',
#  'Amorphus_coralli',
#  'Amphibacillus_xylanus',
#  'Amphimedon_queenslandica',
#  'Amphritea_japonica',
#  'Amycolatopsis_mediterranei',
#  'Anabaena_cylindrica',
#  'Anaeroarcus_burkinensis',
#  'Anaerobiospirillum_succiniciproducens',
#  'Anaerobranca_gottschalkii',
#  'Anaerococcus_prevotii',
#  'Anaerofustis_stercorihominis',
#  'Anaeroglobus_geminatus',
#  'Anaerolinea_thermophila',
#  'Anaeromusa_acidaminophila',
#  'Anaeromyxobacter_dehalogenans',
#  'Anaerophaga_thermohalophila',
#  'Anaerostipes_hadrus']

# %%
with Path("TOL_matches.txt").open("w") as ofh:
    for name in sorted(matched_names):
        ofh.write(f'{name.replace("_", " ")}\n')
