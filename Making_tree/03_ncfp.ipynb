# %%
# !mkdir Helics_ncfp

# %%
# !ncfp --unify_seqid -v -s -l Helices_ncfp/helix1.log helix1n2.fasta Helices_ncfp/helix1.out thomas.harris@strath.a.cuk -d caches/new_ncfp -c ncfp_cache
# Out:
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Initialising cache...
# [WARNING] [ncbi_cds_from_protein.scripts.ncfp]: Not overwriting old cache at caches/new_ncfp/ncfpcache_ncfp_cache.sqlite3...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Parsing sequence input...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Reading sequences from helix1n2.fasta
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: 1051 sequence records read successfully from helix1n2.fasta
# [INFO] [ncbi_cds_from_protein.sequences]: Processing sequences...
# 1/5 Process input sequences:   1%|▏           | 13/1051 [00:06<08:09,  2.12it/s][WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/6-28: CYXM01000011 (not used)
# [WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/6-28: CZAJ01000025 (not used)
# ...

# %%
# !ncfp --unify_seqid -v -s -l Helices_ncfp/helix2.log helix2n2.fasta Helices_ncfp/helix2.out thomas.harris@strath.a.cuk -d caches/new_ncfp -c ncfp_cache --filestem cached --keepcache
# Out:
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Initialising cache...
# [WARNING] [ncbi_cds_from_protein.scripts.ncfp]: Not overwriting old cache at caches/new_ncfp/ncfpcache_ncfp_cache.sqlite3...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Parsing sequence input...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Reading sequences from helix2n2.fasta
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: 1051 sequence records read successfully from helix2n2.fasta
# [INFO] [ncbi_cds_from_protein.sequences]: Processing sequences...
# 1/5 Process input sequences:   1%|▏           | 13/1051 [00:05<06:45,  2.56it/s][WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/49-68: CYXM01000011 (not used)
# [WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/49-68: CZAJ01000025 (not used)
# ...

# %%
# !ncfp --unify_seqid -v -s -l Helices_ncfp/helix3.log helix3n2.fasta Helices_ncfp/helix3.out thomas.harris@strath.a.cuk -d caches/new_ncfp -c ncfp_cache --filestem cached --keepcache
# Out:
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Initialising cache...
# [WARNING] [ncbi_cds_from_protein.scripts.ncfp]: Not overwriting old cache at caches/new_ncfp/ncfpcache_ncfp_cache.sqlite3...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Parsing sequence input...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Reading sequences from helix3n2.fasta
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: 1051 sequence records read successfully from helix3n2.fasta
# [INFO] [ncbi_cds_from_protein.sequences]: Processing sequences...
# ...
# 1/5 Process input sequences:   1%|▏           | 13/1051 [00:04<06:35,  2.62it/s][WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/95-112: CVRQ01000009 (not used)
# [WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/95-112: CYXM01000011 (not used)
# ...

# %%
# !ncfp --unify_seqid -v -s -l Helices_ncfp/helix4.log helix4n2.fasta Helices_ncfp/helix4.out thomas.harris@strath.a.cuk -d caches/new_ncfp -c ncfp_cache --filestem cached --keepcache
# Out:
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Initialising cache...
# [WARNING] [ncbi_cds_from_protein.scripts.ncfp]: Not overwriting old cache at caches/new_ncfp/ncfpcache_ncfp_cache.sqlite3...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Parsing sequence input...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Reading sequences from helix4n2.fasta
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: 1051 sequence records read successfully from helix4n2.fasta
# [INFO] [ncbi_cds_from_protein.sequences]: Processing sequences...
# 1/5 Process input sequences:   1%|▏           | 13/1051 [00:05<07:18,  2.37it/s][WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/119-143: CYXM01000011 (not used)
# [WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/119-143: CZAJ01000025 (not used)
# ...

# %%
# !ncfp --unify_seqid -v -s -l Helices_ncfp/helix5.log helix5n2.fasta Helices_ncfp/helix5.out thomas.harris@strath.a.cuk -d caches/new_ncfp -c ncfp_cache --filestem cached --keepcache
# Out:
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Initialising cache...
# [WARNING] [ncbi_cds_from_protein.scripts.ncfp]: Not overwriting old cache at caches/new_ncfp/ncfpcache_ncfp_cache.sqlite3...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Parsing sequence input...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Reading sequences from helix5n2.fasta
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: 1051 sequence records read successfully from helix5n2.fasta
# [INFO] [ncbi_cds_from_protein.sequences]: Processing sequences...
# ...
# 1/5 Process input sequences:   1%|▏           | 13/1051 [00:04<06:29,  2.66it/s][WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/155-176: CVRQ01000009 (not used)
# [WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/155-176: CYXM01000011 (not used)
# ...

# %%
# !ncfp --unify_seqid -v -s -l Helices_ncfp/helix6.log helix6n2.fasta Helices_ncfp/helix6.out thomas.harris@strath.a.cuk -d caches/new_ncfp -c ncfp_cache --filestem cached --keepcache
# Out:
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Initialising cache...
# [WARNING] [ncbi_cds_from_protein.scripts.ncfp]: Not overwriting old cache at caches/new_ncfp/ncfpcache_ncfp_cache.sqlite3...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Parsing sequence input...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Reading sequences from helix6n2.fasta
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: 1051 sequence records read successfully from helix6n2.fasta
# [INFO] [ncbi_cds_from_protein.sequences]: Processing sequences...
# 1/5 Process input sequences:   1%|▏           | 13/1051 [00:14<07:22,  2.35it/s][WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/197-219: CYXM01000011 (not used)
# [WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/197-219: CZAJ01000025 (not used)
# ...

# %%
# !ncfp --unify_seqid -v -s -l Helices_ncfp/helix7.log helix7n2.fasta Helices_ncfp/helix7.out thomas.harris@strath.a.cuk -d caches/new_ncfp -c ncfp_cache --filestem cached --keepcache
# Out:
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Initialising cache...
# [WARNING] [ncbi_cds_from_protein.scripts.ncfp]: Not overwriting old cache at caches/new_ncfp/ncfpcache_ncfp_cache.sqlite3...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Parsing sequence input...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Reading sequences from helix7n2.fasta
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: 1051 sequence records read successfully from helix7n2.fasta
# [INFO] [ncbi_cds_from_protein.sequences]: Processing sequences...
# ...
# 1/5 Process input sequences:   1%|▏           | 13/1051 [00:05<06:42,  2.58it/s][WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/231-254: CYXM01000011 (not used)
# [WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/231-254: CZAJ01000025 (not used)
# ...

# %%
# !ncfp --unify_seqid -v -s -l Helices_ncfp/helix8.log helix8n2.fasta Helices_ncfp/helix8.out thomas.harris@strath.a.cuk -d caches/new_ncfp -c ncfp_cache --filestem cached --keepcache
# Out:
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Initialising cache...
# [WARNING] [ncbi_cds_from_protein.scripts.ncfp]: Not overwriting old cache at caches/new_ncfp/ncfpcache_ncfp_cache.sqlite3...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Parsing sequence input...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Reading sequences from helix8n2.fasta
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: 1051 sequence records read successfully from helix8n2.fasta
# [INFO] [ncbi_cds_from_protein.sequences]: Processing sequences...
# 1/5 Process input sequences:   1%|▏           | 13/1051 [00:05<06:49,  2.54it/s][WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/261-278: CYXM01000011 (not used)
# [WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/261-278: CZAJ01000025 (not used)
# ...

# %%
# !ncfp --unify_seqid -v -s -l Helices_ncfp/helix9.log helix9n2.fasta Helices_ncfp/helix9.out thomas.harris@strath.a.cuk -d caches/new_ncfp -c ncfp_cache --filestem cached --keepcache
# Out:
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Initialising cache...
# [WARNING] [ncbi_cds_from_protein.scripts.ncfp]: Not overwriting old cache at caches/new_ncfp/ncfpcache_ncfp_cache.sqlite3...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Parsing sequence input...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Reading sequences from helix9n2.fasta
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: 1051 sequence records read successfully from helix9n2.fasta
# [INFO] [ncbi_cds_from_protein.sequences]: Processing sequences...
# ...
# 1/5 Process input sequences:   1%|▏           | 13/1051 [00:04<06:36,  2.62it/s][WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/284-305: CYXM01000011 (not used)
# [WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/284-305: CZAJ01000025 (not used)
# ...

# %%
# !ncfp --unify_seqid -v -s -l Helices_ncfp/helix10.log helix10n2.fasta Helices_ncfp/helix10.out thomas.harris@strath.a.cuk -d caches/new_ncfp -c ncfp_cache --filestem cached --keepcache
# Out:
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Initialising cache...
# [WARNING] [ncbi_cds_from_protein.scripts.ncfp]: Not overwriting old cache at caches/new_ncfp/ncfpcache_ncfp_cache.sqlite3...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Parsing sequence input...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Reading sequences from helix10n2.fasta
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: 1051 sequence records read successfully from helix10n2.fasta
# [INFO] [ncbi_cds_from_protein.sequences]: Processing sequences...
# 1/5 Process input sequences:   1%|▏           | 13/1051 [00:05<07:01,  2.46it/s][WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/326-346: CYXM01000011 (not used)
# [WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/326-346: CZAJ01000025 (not used)
# ...

# %%
# !ncfp --unify_seqid -v -s -l Helices_ncfp/helix11.log helix11n2.fasta Helices_ncfp/helix11.out thomas.harris@strath.a.cuk -d caches/new_ncfp -c ncfp_cache --filestem cached --keepcache
# Out:
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Initialising cache...
# [WARNING] [ncbi_cds_from_protein.scripts.ncfp]: Not overwriting old cache at caches/new_ncfp/ncfpcache_ncfp_cache.sqlite3...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Parsing sequence input...
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: Reading sequences from helix11n2.fasta
# [INFO] [ncbi_cds_from_protein.scripts.ncfp]: 1051 sequence records read successfully from helix11n2.fasta
# [INFO] [ncbi_cds_from_protein.sequences]: Processing sequences...
# 1/5 Process input sequences:   1%|▏           | 13/1051 [00:05<06:47,  2.55it/s][WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/366-390: CYXM01000011 (not used)
# [WARNING] [ncbi_cds_from_protein.sequences]: Additional query terms found for tr|A0A0M6WCZ2|A0A0M6WCZ2_9FIRM/366-390: CZAJ01000025 (not used)
# ...
