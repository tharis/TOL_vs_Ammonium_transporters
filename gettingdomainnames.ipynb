# %%
# Essential imports
import re

from io import StringIO

import pandas as pd
import numpy as np

from Bio import SeqIO
from bioservices import UniProt
from bioservices import Pfam

import tqdm
from pathlib import Path

# We'll need ETE3 to parse and render the tree
from ete3 import Tree, TreeStyle, NodeStyle, TextFace, CircleFace, faces, SeqMotifFace
from tqdm.notebook import tqdm
import pandas as pd
# Connect to UniProt service
u = UniProt(verbose=False)

# %%
#!/usr/bin/env python3

import json
import ssl
import time
from urllib import request
from urllib.error import HTTPError

BASE_URL = "https://www.ebi.ac.uk/interpro/api/entry/pfam/protein/UniProt/"

def fetch_interpro_data(uniprotid):
    """Query InterPro API for a single UniProt ID and return results as a list"""

    context = ssl._create_unverified_context()
    next_url = f"{BASE_URL}{uniprotid}"
    last_page = False
    results = []

    attempts = 0
    while next_url:
        try:
            req = request.Request(next_url, headers={"Accept": "application/json"})
            res = request.urlopen(req, context=context)

            if res.status == 408:
                time.sleep(61)
                continue
            elif res.status == 204:
                break

            payload = json.loads(res.read().decode())
            next_url = payload.get("next", None)
            attempts = 0

            if not next_url:
                last_page = True

        except HTTPError as e:
            if e.code == 408:
                time.sleep(61)
                continue
            elif attempts < 3:
                attempts += 1
                time.sleep(61)
                continue
            else:
                print(f"ERROR: {uniprotid} - {e}")
                return []

        # Append results for this UniProt ID
        results.extend(payload["results"])

        if next_url:
            time.sleep(1)  # Prevent API overload

    return results

# List of UniProt IDs to search
# extradomains = ["P69905", "P68871", "Q9Y2Z9", "P05067"]  # Replace with your actual IDs

# Dictionary to store results
interpro_results = {}

# Loop through each UniProt ID and store results
for uniprotid in extradomains:
    interpro_results[uniprotid] = fetch_interpro_data(uniprotid)

# Now interpro_results is a dictionary with UniProt IDs as keys and InterPro data as values

# Print the first few results for testing
for uniprotid, data in interpro_results.items():
    print(f"{uniprotid}: {data[:2]}")  # Show only first 2 entries per ID for readability

# Optionally, save results to a JSON file
with open("interpro_results.json", "w") as f:
    json.dump(interpro_results, f, indent=4)
# Out:
# A0A066ZRQ5: [{'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a066zrq5', 'protein_length': 611, 'source_database': 'unreviewed', 'organism': '28885', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 9, 'end': 385, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 4.5e-101}]}]}, {'metadata': {'accession': 'PF00990', 'name': 'Diguanylate cyclase, GGDEF domain', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR000160', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a066zrq5', 'protein_length': 611, 'source_database': 'unreviewed', 'organism': '28885', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 448, 'end': 606, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00990', 'score': 4.6e-41}]}]}]
# A0A173R3X4: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a173r3x4', 'protein_length': 581, 'source_database': 'unreviewed', 'organism': '649756', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 466, 'end': 571, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 1.6e-18}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a173r3x4', 'protein_length': 581, 'source_database': 'unreviewed', 'organism': '649756', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 16, 'end': 411, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 4.9e-116}]}]}]
# A0A1Y4L5P0: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a1y4l5p0', 'protein_length': 573, 'source_database': 'unreviewed', 'organism': '501571', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 460, 'end': 564, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 9.9e-20}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a1y4l5p0', 'protein_length': 573, 'source_database': 'unreviewed', 'organism': '501571', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 15, 'end': 407, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 9e-121}]}]}]
# A0A1Y4LM49: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a1y4lm49', 'protein_length': 574, 'source_database': 'unreviewed', 'organism': '501571', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 461, 'end': 565, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 1.8e-19}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a1y4lm49', 'protein_length': 574, 'source_database': 'unreviewed', 'organism': '501571', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 15, 'end': 407, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 9.4e-121}]}]}]
# A0A2C9CK98: [{'metadata': {'accession': 'PF00512', 'name': 'His Kinase A (phospho-acceptor) domain', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR003661', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a2c9ck98', 'protein_length': 679, 'source_database': 'unreviewed', 'organism': '174633', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 451, 'end': 518, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00512', 'score': 9e-20}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a2c9ck98', 'protein_length': 679, 'source_database': 'unreviewed', 'organism': '174633', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 11, 'end': 408, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 4.6e-108}]}]}]
# A0A2G3DSU6: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a2g3dsu6', 'protein_length': 581, 'source_database': 'unreviewed', 'organism': '46206', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 466, 'end': 571, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 8.5e-20}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a2g3dsu6', 'protein_length': 581, 'source_database': 'unreviewed', 'organism': '46206', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 11, 'end': 406, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 5.7e-116}]}]}]
# A0A2G3E8V2: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a2g3e8v2', 'protein_length': 581, 'source_database': 'unreviewed', 'organism': '46206', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 466, 'end': 571, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 8.5e-20}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a2g3e8v2', 'protein_length': 581, 'source_database': 'unreviewed', 'organism': '46206', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 11, 'end': 406, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 3.4e-115}]}]}]
# A0A2K3DQF8: [{'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a2k3dqf8', 'protein_length': 782, 'source_database': 'unreviewed', 'organism': '3055', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 17, 'end': 451, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 9.1e-106}]}]}, {'metadata': {'accession': 'PF05021', 'name': 'NPL4 family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR007717', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a2k3dqf8', 'protein_length': 782, 'source_database': 'unreviewed', 'organism': '3055', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 527, 'end': 649, 'dc-status': 'CONTINUOUS'}], 'representative': True, 'model': 'PF05021', 'score': 5.9e-10}, {'fragments': [{'start': 701, 'end': 763, 'dc-status': 'CONTINUOUS'}], 'representative': True, 'model': 'PF05021', 'score': 0.055}]}]}]
# A0A317G0I6: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a317g0i6', 'protein_length': 591, 'source_database': 'unreviewed', 'organism': '831', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 477, 'end': 581, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 3.1e-18}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a317g0i6', 'protein_length': 591, 'source_database': 'unreviewed', 'organism': '831', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 16, 'end': 420, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 1.2e-116}]}]}]
# A0A3E2T713: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a3e2t713', 'protein_length': 580, 'source_database': 'unreviewed', 'organism': '853', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 465, 'end': 570, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 3.2e-21}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a3e2t713', 'protein_length': 580, 'source_database': 'unreviewed', 'organism': '853', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 9, 'end': 406, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 2.7e-119}]}]}]
# A0A3E2TW06: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a3e2tw06', 'protein_length': 579, 'source_database': 'unreviewed', 'organism': '853', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 464, 'end': 569, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 1.5e-20}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a3e2tw06', 'protein_length': 579, 'source_database': 'unreviewed', 'organism': '853', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 9, 'end': 405, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 1.2e-118}]}]}]
# A0A3E2UCG9: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a3e2ucg9', 'protein_length': 580, 'source_database': 'unreviewed', 'organism': '853', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 465, 'end': 570, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 2.9e-21}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a3e2ucg9', 'protein_length': 580, 'source_database': 'unreviewed', 'organism': '853', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 9, 'end': 405, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 1.7e-119}]}]}]
# A0A3E2UHE6: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a3e2uhe6', 'protein_length': 579, 'source_database': 'unreviewed', 'organism': '853', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 464, 'end': 569, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 1.5e-20}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a3e2uhe6', 'protein_length': 579, 'source_database': 'unreviewed', 'organism': '853', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 9, 'end': 405, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 2.3e-119}]}]}]
# A0A3E2VY88: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a3e2vy88', 'protein_length': 579, 'source_database': 'unreviewed', 'organism': '853', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 464, 'end': 569, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 1.5e-20}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a3e2vy88', 'protein_length': 579, 'source_database': 'unreviewed', 'organism': '853', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 9, 'end': 405, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 2.2e-119}]}]}]
# A0A5P9P1L2: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a5p9p1l2', 'protein_length': 550, 'source_database': 'unreviewed', 'organism': '348826', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 440, 'end': 544, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 5.6e-23}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a5p9p1l2', 'protein_length': 550, 'source_database': 'unreviewed', 'organism': '348826', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 21, 'end': 407, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 3.7e-91}]}]}]
# A0A6N2TIA4: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a6n2tia4', 'protein_length': 581, 'source_database': 'unreviewed', 'organism': '649756', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 466, 'end': 571, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 1.6e-18}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a6n2tia4', 'protein_length': 581, 'source_database': 'unreviewed', 'organism': '649756', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 16, 'end': 411, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 1.3e-115}]}]}]
# A0A833GZR2: [{'metadata': {'accession': 'PF00211', 'name': 'Adenylate and Guanylate cyclase catalytic domain', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR001054', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a833gzr2', 'protein_length': 681, 'source_database': 'unreviewed', 'organism': '183', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 498, 'end': 675, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00211', 'score': 6.7e-55}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a0a833gzr2', 'protein_length': 681, 'source_database': 'unreviewed', 'organism': '183', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 9, 'end': 401, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 2.6e-107}]}]}]
# A1SY01: [{'metadata': {'accession': 'PF00563', 'name': 'EAL domain', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR001633', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a1sy01', 'protein_length': 1016, 'source_database': 'unreviewed', 'organism': '357804', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 765, 'end': 999, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00563', 'score': 4.2e-66}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a1sy01', 'protein_length': 1016, 'source_database': 'unreviewed', 'organism': '357804', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 5, 'end': 393, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 7.5e-120}]}]}]
# A7HT14: [{'metadata': {'accession': 'PF00512', 'name': 'His Kinase A (phospho-acceptor) domain', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR003661', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a7ht14', 'protein_length': 717, 'source_database': 'unreviewed', 'organism': '402881', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 478, 'end': 546, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00512', 'score': 8.7e-18}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'a7ht14', 'protein_length': 717, 'source_database': 'unreviewed', 'organism': '402881', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 12, 'end': 406, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 2.1e-114}]}]}]
# B9LU00: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'b9lu00', 'protein_length': 562, 'source_database': 'unreviewed', 'organism': '416348', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 452, 'end': 555, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 5.6e-23}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'b9lu00', 'protein_length': 562, 'source_database': 'unreviewed', 'organism': '416348', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 22, 'end': 412, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 1e-83}]}]}]
# C6LBD3: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'c6lbd3', 'protein_length': 614, 'source_database': 'unreviewed', 'organism': '478749', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 501, 'end': 604, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 5e-19}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'c6lbd3', 'protein_length': 614, 'source_database': 'unreviewed', 'organism': '478749', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 34, 'end': 443, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 1.5e-115}]}]}]
# C7LQR9: [{'metadata': {'accession': 'PF00563', 'name': 'EAL domain', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR001633', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'c7lqr9', 'protein_length': 1262, 'source_database': 'unreviewed', 'organism': '525897', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 1004, 'end': 1242, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00563', 'score': 2.9e-76}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'c7lqr9', 'protein_length': 1262, 'source_database': 'unreviewed', 'organism': '525897', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 7, 'end': 398, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 3.5e-112}]}]}]
# D2RU19: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'd2ru19', 'protein_length': 555, 'source_database': 'unreviewed', 'organism': '543526', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 445, 'end': 549, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 1.4e-24}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'd2ru19', 'protein_length': 555, 'source_database': 'unreviewed', 'organism': '543526', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 23, 'end': 412, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 1.3e-93}]}]}]
# D4H5F9: [{'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'd4h5f9', 'protein_length': 631, 'source_database': 'unreviewed', 'organism': '522772', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 9, 'end': 398, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 3.8e-111}]}]}, {'metadata': {'accession': 'PF00990', 'name': 'Diguanylate cyclase, GGDEF domain', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR000160', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'd4h5f9', 'protein_length': 631, 'source_database': 'unreviewed', 'organism': '522772', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 461, 'end': 617, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00990', 'score': 1.8e-40}]}]}]
# D8J4C6: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'd8j4c6', 'protein_length': 550, 'source_database': 'unreviewed', 'organism': '795797', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 440, 'end': 543, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 6.2e-23}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'd8j4c6', 'protein_length': 550, 'source_database': 'unreviewed', 'organism': '795797', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 15, 'end': 411, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 2e-88}]}]}]
# F7ZJM0: [{'metadata': {'accession': 'PF00563', 'name': 'EAL domain', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR001633', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'f7zjm0', 'protein_length': 908, 'source_database': 'unreviewed', 'organism': '391595', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 655, 'end': 886, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00563', 'score': 2.3e-56}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'f7zjm0', 'protein_length': 908, 'source_database': 'unreviewed', 'organism': '391595', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 7, 'end': 395, 'dc-status': 'CONTINUOUS'}], 'representative': True, 'model': 'PF00909', 'score': 1.4e-93}]}]}]
# F8D7H6: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'f8d7h6', 'protein_length': 558, 'source_database': 'unreviewed', 'organism': '797210', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 448, 'end': 552, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 1.3e-24}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'f8d7h6', 'protein_length': 558, 'source_database': 'unreviewed', 'organism': '797210', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 21, 'end': 406, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 3e-91}]}]}]
# G4QHD2: [{'metadata': {'accession': 'PF00563', 'name': 'EAL domain', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR001633', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'g4qhd2', 'protein_length': 1016, 'source_database': 'unreviewed', 'organism': '1085623', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 764, 'end': 999, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00563', 'score': 3.9e-66}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'g4qhd2', 'protein_length': 1016, 'source_database': 'unreviewed', 'organism': '1085623', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 5, 'end': 393, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 5.8e-113}]}]}]
# G7WFX2: [{'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'g7wfx2', 'protein_length': 643, 'source_database': 'unreviewed', 'organism': '768706', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 6, 'end': 397, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 2.4e-93}]}]}, {'metadata': {'accession': 'PF02518', 'name': 'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR003594', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'g7wfx2', 'protein_length': 643, 'source_database': 'unreviewed', 'organism': '768706', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 553, 'end': 641, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF02518', 'score': 8.6e-08}]}]}]
# H2CJI0: [{'metadata': {'accession': 'PF00211', 'name': 'Adenylate and Guanylate cyclase catalytic domain', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR001054', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'h2cji0', 'protein_length': 681, 'source_database': 'unreviewed', 'organism': '929563', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 498, 'end': 675, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00211', 'score': 6.7e-55}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'h2cji0', 'protein_length': 681, 'source_database': 'unreviewed', 'organism': '929563', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 9, 'end': 401, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 6.2e-107}]}]}]
# H6LKX6: [{'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'h6lkx6', 'protein_length': 624, 'source_database': 'unreviewed', 'organism': '931626', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 8, 'end': 402, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 5.5e-114}]}]}, {'metadata': {'accession': 'PF00990', 'name': 'Diguanylate cyclase, GGDEF domain', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR000160', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'h6lkx6', 'protein_length': 624, 'source_database': 'unreviewed', 'organism': '931626', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 467, 'end': 621, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00990', 'score': 1.1e-36}]}]}]
# I4D6Z9: [{'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'i4d6z9', 'protein_length': 643, 'source_database': 'unreviewed', 'organism': '646529', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 6, 'end': 398, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 3.7e-100}]}]}, {'metadata': {'accession': 'PF02518', 'name': 'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR003594', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'i4d6z9', 'protein_length': 643, 'source_database': 'unreviewed', 'organism': '646529', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 554, 'end': 642, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF02518', 'score': 7e-07}]}]}]
# L0JT30: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'l0jt30', 'protein_length': 548, 'source_database': 'unreviewed', 'organism': '797303', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 438, 'end': 542, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 1.6e-22}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'l0jt30', 'protein_length': 548, 'source_database': 'unreviewed', 'organism': '797303', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 22, 'end': 408, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 8.3e-92}]}]}]
# M0MDP9: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'm0mdp9', 'protein_length': 572, 'source_database': 'unreviewed', 'organism': '1227455', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 462, 'end': 565, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 2.7e-23}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'm0mdp9', 'protein_length': 572, 'source_database': 'unreviewed', 'organism': '1227455', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 24, 'end': 423, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 9.3e-88}]}]}]
# Q1K433: [{'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'q1k433', 'protein_length': 606, 'source_database': 'unreviewed', 'organism': '281689', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 11, 'end': 389, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 2.6e-103}]}]}, {'metadata': {'accession': 'PF00990', 'name': 'Diguanylate cyclase, GGDEF domain', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR000160', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'q1k433', 'protein_length': 606, 'source_database': 'unreviewed', 'organism': '281689', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 454, 'end': 602, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00990', 'score': 2.7e-38}]}]}]
# Q1Q357: [{'metadata': {'accession': 'PF00512', 'name': 'His Kinase A (phospho-acceptor) domain', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR003661', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'q1q357', 'protein_length': 679, 'source_database': 'unreviewed', 'organism': '174633', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 451, 'end': 518, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00512', 'score': 9e-20}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'q1q357', 'protein_length': 679, 'source_database': 'unreviewed', 'organism': '174633', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 11, 'end': 408, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 1.1e-107}]}]}]
# R8VWI7: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'r8vwi7', 'protein_length': 574, 'source_database': 'unreviewed', 'organism': '1203606', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 461, 'end': 565, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 1.8e-19}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'r8vwi7', 'protein_length': 574, 'source_database': 'unreviewed', 'organism': '1203606', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 15, 'end': 407, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 9.7e-121}]}]}]
# W0E077: [{'metadata': {'accession': 'PF00015', 'name': 'Methyl-accepting chemotaxis protein (MCP) signalling domain', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR004089', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'w0e077', 'protein_length': 720, 'source_database': 'unreviewed', 'organism': '765910', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 533, 'end': 686, 'dc-status': 'CONTINUOUS'}], 'representative': True, 'model': 'PF00015', 'score': 1.2e-34}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'w0e077', 'protein_length': 720, 'source_database': 'unreviewed', 'organism': '765910', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 1, 'end': 393, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 9e-114}]}]}]
# W0JIB3: [{'metadata': {'accession': 'PF00543', 'name': 'Nitrogen regulatory protein P-II', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR002187', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'w0jib3', 'protein_length': 584, 'source_database': 'unreviewed', 'organism': '797299', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 474, 'end': 578, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00543', 'score': 1.1e-23}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'w0jib3', 'protein_length': 584, 'source_database': 'unreviewed', 'organism': '797299', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 20, 'end': 425, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 2.9e-92}]}]}]
# W7QGM4: [{'metadata': {'accession': 'PF00563', 'name': 'EAL domain', 'source_database': 'pfam', 'type': 'domain', 'integrated': 'IPR001633', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'w7qgm4', 'protein_length': 1136, 'source_database': 'unreviewed', 'organism': '1328313', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 885, 'end': 1119, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00563', 'score': 7.5e-59}]}]}, {'metadata': {'accession': 'PF00909', 'name': 'Ammonium Transporter Family', 'source_database': 'pfam', 'type': 'family', 'integrated': 'IPR024041', 'member_databases': None, 'go_terms': None}, 'proteins': [{'accession': 'w7qgm4', 'protein_length': 1136, 'source_database': 'unreviewed', 'organism': '1328313', 'in_alphafold': True, 'entry_protein_locations': [{'fragments': [{'start': 6, 'end': 396, 'dc-status': 'CONTINUOUS'}], 'representative': False, 'model': 'PF00909', 'score': 8e-101}]}]}]

# %%
interpro_results_extra
# Out:
# {'A0A377PLP5': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a377plp5',
#      'protein_length': 430,
#      'source_database': 'unreviewed',
#      'organism': '569',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 35,
#          'end': 428,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2.3e-123}]}]}],
#  'A0A097R891': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a097r891',
#      'protein_length': 429,
#      'source_database': 'unreviewed',
#      'organism': '1453496',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 34,
#          'end': 427,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 7.9e-124}]}]}],
#  'A0A377PBY1': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a377pby1',
#      'protein_length': 430,
#      'source_database': 'unreviewed',
#      'organism': '569',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 35,
#          'end': 428,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 5.3e-124}]}]}],
#  'A0A1C6Z081': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1c6z081',
#      'protein_length': 430,
#      'source_database': 'unreviewed',
#      'organism': '569',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 35,
#          'end': 428,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 7.8e-124}]}]}],
#  'G9Y5B0': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'g9y5b0',
#      'protein_length': 429,
#      'source_database': 'unreviewed',
#      'organism': '1002364',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 34,
#          'end': 427,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.8e-122}]}]}],
#  'A0A2A2M8K7': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a2a2m8k7',
#      'protein_length': 429,
#      'source_database': 'unreviewed',
#      'organism': '546367',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 34,
#          'end': 427,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.5e-122}]}]}],
#  'E0SD83': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'e0sd83',
#      'protein_length': 430,
#      'source_database': 'unreviewed',
#      'organism': '198628',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 35,
#          'end': 428,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.3e-120}]}]}],
#  'D2BUJ8': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'd2buj8',
#      'protein_length': 430,
#      'source_database': 'unreviewed',
#      'organism': '590409',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 35,
#          'end': 428,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 7.3e-121}]}]}],
#  'C6CBB1': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'c6cbb1',
#      'protein_length': 430,
#      'source_database': 'unreviewed',
#      'organism': '579405',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 35,
#          'end': 428,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.5e-120}]}]}],
#  'A0A1X3RP39': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1x3rp39',
#      'protein_length': 430,
#      'source_database': 'unreviewed',
#      'organism': '1082703',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 35,
#          'end': 428,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 7.1e-123}]}]}],
#  'A0A1H3WA00': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1h3wa00',
#      'protein_length': 430,
#      'source_database': 'unreviewed',
#      'organism': '71657',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 35,
#          'end': 428,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 3.7e-124}]}]}],
#  'A0A5C4RNH5': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a5c4rnh5',
#      'protein_length': 427,
#      'source_database': 'unreviewed',
#      'organism': '1173677',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 4.3e-121}]}]}],
#  'A0A1G5PWV0': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1g5pwv0',
#      'protein_length': 439,
#      'source_database': 'unreviewed',
#      'organism': '29488',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 45,
#          'end': 438,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 8.3e-122}]}]}],
#  'A0A4V2X6C2': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a4v2x6c2',
#      'protein_length': 427,
#      'source_database': 'unreviewed',
#      'organism': '2100167',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.6e-121}]}]}],
#  'A0A2S8QA29': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a2s8qa29',
#      'protein_length': 439,
#      'source_database': 'unreviewed',
#      'organism': '29488',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 45,
#          'end': 438,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2.9e-121}]}]}],
#  'Q7N0M6': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'q7n0m6',
#      'protein_length': 439,
#      'source_database': 'unreviewed',
#      'organism': '243265',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 45,
#          'end': 438,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2.5e-119}]}]}],
#  'A0A4R4K1P9': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a4r4k1p9',
#      'protein_length': 427,
#      'source_database': 'unreviewed',
#      'organism': '2100166',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 8.2e-121}]}]}],
#  'C7BJG7': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'c7bjg7',
#      'protein_length': 427,
#      'source_database': 'unreviewed',
#      'organism': '553480',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.5e-119}]}]}],
#  'A0A1B9NQ91': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1b9nq91',
#      'protein_length': 426,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 32,
#          'end': 424,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 7.6e-115}]}]}],
#  'A0A1B9M1A9': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1b9m1a9',
#      'protein_length': 426,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 32,
#          'end': 424,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2e-114}]}]}],
#  'A0A1B9N3H7': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1b9n3h7',
#      'protein_length': 426,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 32,
#          'end': 424,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.7e-113}]}]}],
#  'A0A657K391': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a657k391',
#      'protein_length': 426,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 32,
#          'end': 424,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.4e-115}]}]}],
#  'A0A1B9LFW3': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1b9lfw3',
#      'protein_length': 426,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 32,
#          'end': 424,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 4.6e-114}]}]}],
#  'A0A1B9M5B8': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1b9m5b8',
#      'protein_length': 426,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 32,
#          'end': 424,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 7.2e-114}]}]}],
#  'A0A1B9MBX6': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1b9mbx6',
#      'protein_length': 426,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 32,
#          'end': 424,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2.3e-114}]}]}],
#  'A0A1B9MZ78': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1b9mz78',
#      'protein_length': 426,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 32,
#          'end': 424,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 6.6e-114}]}]}],
#  'A0A556RTU3': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a556rtu3',
#      'protein_length': 426,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 32,
#          'end': 424,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 3.9e-117}]}]}],
#  'A0A2V4EA49': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a2v4ea49',
#      'protein_length': 426,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 32,
#          'end': 424,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 8.7e-116}]}]}],
#  'A0A1C0A1D9': [],
#  'A0A1B9MYL7': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1b9myl7',
#      'protein_length': 427,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 424,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 7.9e-113}]}]}],
#  'A0A1B9JHS5': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1b9jhs5',
#      'protein_length': 427,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 425,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 6.4e-116}]}]}],
#  'A0A556SRH6': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a556srh6',
#      'protein_length': 427,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 425,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 5.2e-116}]}]}],
#  'A0A242NIL1': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a242nil1',
#      'protein_length': 427,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 425,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 8.6e-117}]}]}],
#  'A0A1B9KID3': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1b9kid3',
#      'protein_length': 426,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 32,
#          'end': 424,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 8.9e-118}]}]}],
#  'A0A1B9JPL5': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1b9jpl5',
#      'protein_length': 426,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 32,
#          'end': 424,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1e-116}]}]}],
#  'A0A1B9K8L2': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1b9k8l2',
#      'protein_length': 426,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 32,
#          'end': 424,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.2e-113}]}]}],
#  'A0A1B9JZS5': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1b9jzs5',
#      'protein_length': 426,
#      'source_database': 'unreviewed',
#      'organism': '1196095',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 32,
#          'end': 424,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.6e-113}]}]}],
#  'A0A140NHJ5': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a140nhj5',
#      'protein_length': 427,
#      'source_database': 'unreviewed',
#      'organism': '1157951',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.2e-115}]}]}],
#  'A0AA86YS65': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0aa86ys65',
#      'protein_length': 435,
#      'source_database': 'unreviewed',
#      'organism': '471874',
#      'in_alphafold': False,
#      'entry_protein_locations': [{'fragments': [{'start': 41,
#          'end': 434,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.3e-115}]}]}],
#  'A0A1S1HRJ0': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1s1hrj0',
#      'protein_length': 427,
#      'source_database': 'unreviewed',
#      'organism': '588',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 9.4e-117}]}]}],
#  'K8VZC6': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'k8vzc6',
#      'protein_length': 427,
#      'source_database': 'unreviewed',
#      'organism': '1141660',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2.5e-118}]}]}],
#  'A0A264VQM8': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a264vqm8',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '587',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 34,
#          'end': 427,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.5e-117}]}]}],
#  'K8W1E2': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'k8w1e2',
#      'protein_length': 427,
#      'source_database': 'unreviewed',
#      'organism': '1141662',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.7e-115}]}]}],
#  'A0A1Z1SZE8': [],
#  'A0A2X2C038': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a2x2c038',
#      'protein_length': 432,
#      'source_database': 'unreviewed',
#      'organism': '584',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 37,
#          'end': 430,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.7e-121}]}]}],
#  'A0A4R3NLV5': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a4r3nlv5',
#      'protein_length': 430,
#      'source_database': 'unreviewed',
#      'organism': '126385',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 34,
#          'end': 428,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 4.2e-122}]}]}],
#  'A0A0G3CP57': [],
#  'A0A2C6C0X3': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a2c6c0x3',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '82979',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.6e-118}]}]}],
#  'A0A2A7U6W1': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a2a7u6w1',
#      'protein_length': 425,
#      'source_database': 'unreviewed',
#      'organism': '636',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 31,
#          'end': 423,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 3.5e-118}]}]}],
#  'D4F313': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'd4f313',
#      'protein_length': 434,
#      'source_database': 'unreviewed',
#      'organism': '500638',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 40,
#          'end': 432,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 3.8e-118}]}]}],
#  'A0A0H3DR67': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a0h3dr67',
#      'protein_length': 416,
#      'source_database': 'unreviewed',
#      'organism': '718251',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 22,
#          'end': 414,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.6e-119}]}]}],
#  'A0A433ZQ80': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a433zq80',
#      'protein_length': 429,
#      'source_database': 'unreviewed',
#      'organism': '582',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 34,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 9.6e-120}]}]}],
#  'M1SJL5': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'm1sjl5',
#      'protein_length': 429,
#      'source_database': 'unreviewed',
#      'organism': '1124991',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 34,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 9.1e-119}]}]}],
#  'A0A4R7GKA0': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a4r7gka0',
#      'protein_length': 429,
#      'source_database': 'unreviewed',
#      'organism': '2485117',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 34,
#          'end': 427,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.8e-122}]}]}],
#  'H2IZ00': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'h2iz00',
#      'protein_length': 429,
#      'source_database': 'unreviewed',
#      'organism': '745277',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 34,
#          'end': 427,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 4.6e-122}]}]}],
#  'A0A4R2Z2K6': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a4r2z2k6',
#      'protein_length': 429,
#      'source_database': 'unreviewed',
#      'organism': '2485128',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 34,
#          'end': 427,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.8e-122}]}]}],
#  'A0A502GPV4': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a502gpv4',
#      'protein_length': 429,
#      'source_database': 'unreviewed',
#      'organism': '41202',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 34,
#          'end': 427,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 8.1e-120}]}]}],
#  'A0A2N0MZ27': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a2n0mz27',
#      'protein_length': 429,
#      'source_database': 'unreviewed',
#      'organism': '41202',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 34,
#          'end': 427,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.1e-119}]}]}],
#  'A0A087L0B9': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a087l0b9',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '1524467',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2.3e-121}]}]}],
#  'A0A419AVL2': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a419avl2',
#      'protein_length': 430,
#      'source_database': 'unreviewed',
#      'organism': '554',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 35,
#          'end': 428,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.7e-122}]}]}],
#  'A0AA86DEY7': [],
#  'A0AA40J491': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0aa40j491',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '555',
#      'in_alphafold': False,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.6e-122}]}]}],
#  'C6DB68': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'c6db68',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '561230',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2.9e-122}]}]}],
#  'A0A7V8IKS6': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a7v8iks6',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '2558042',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 3.9e-122}]}]}],
#  'A0A366IE34': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a366ie34',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '714314',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 4.4e-122}]}]}],
#  'A0A830ZZN8': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a830zzn8',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '1219359',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 4.5e-125}]}]}],
#  'E5B358': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'e5b358',
#      'protein_length': 433,
#      'source_database': 'unreviewed',
#      'organism': '889211',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 38,
#          'end': 431,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 5.9e-125}]}]}],
#  'A0A3N1VXY4': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a3n1vxy4',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '2485126',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.1e-124}]}]}],
#  'D4GLQ6': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'd4glq6',
#      'protein_length': 435,
#      'source_database': 'unreviewed',
#      'organism': '706191',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 40,
#          'end': 433,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 3.1e-123}]}]}],
#  'A0A0H3KTD3': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a0h3ktd3',
#      'protein_length': 434,
#      'source_database': 'unreviewed',
#      'organism': '932677',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 39,
#          'end': 432,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 3e-123}]}]}],
#  'A0A1Y6GLJ1': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1y6glj1',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '54291',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2e-124}]}]}],
#  'A0A855F5Y8': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a855f5y8',
#      'protein_length': 423,
#      'source_database': 'unreviewed',
#      'organism': '54291',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 28,
#          'end': 421,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.9e-124}]}]}],
#  'A0A318FY98': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a318fy98',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '571',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.4e-124}]}]}],
#  'A0A6B8N021': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a6b8n021',
#      'protein_length': 423,
#      'source_database': 'unreviewed',
#      'organism': '571',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 28,
#          'end': 421,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2e-125}]}]}],
#  'A0A0H3H4I7': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a0h3h4i7',
#      'protein_length': 423,
#      'source_database': 'unreviewed',
#      'organism': '1006551',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 28,
#          'end': 421,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.1e-124}]}]}],
#  'A0A168EVK8': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a168evk8',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '571',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.5e-124}]}]}],
#  'V5U2Z4': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'v5u2z4',
#      'protein_length': 431,
#      'source_database': 'unreviewed',
#      'organism': '413503',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 36,
#          'end': 429,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1e-126}]}]}],
#  'A0A423Y4I6': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a423y4i6',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '413503',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2.3e-126}]}]}],
#  'A7MFK3': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a7mfk3',
#      'protein_length': 431,
#      'source_database': 'unreviewed',
#      'organism': '290339',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 36,
#          'end': 429,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1e-125}]}]}],
#  'A0A381CAY8': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a381cay8',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '82977',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 4.4e-127}]}]}],
#  'A0A085GI50': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a085gi50',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '1006004',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.5e-127}]}]}],
#  'A0A2T2Y0D5': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a2t2y0d5',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '2774054',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 4.1e-126}]}]}],
#  'A0A3N2SFS2': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a3n2sfs2',
#      'protein_length': 428,
#      'source_database': 'unreviewed',
#      'organism': '51288',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 33,
#          'end': 426,
# ...
#      'source_database': 'unreviewed',
#      'organism': '853',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 464,
#          'end': 569,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00543',
#        'score': 1.5e-20}]}]},
#   {'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a3e2vy88',
#      'protein_length': 579,
#      'source_database': 'unreviewed',
#      'organism': '853',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 9,
#          'end': 405,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2.2e-119}]}]}],
#  'A0A3E2T713': [{'metadata': {'accession': 'PF00543',
#     'name': 'Nitrogen regulatory protein P-II',
#     'source_database': 'pfam',
#     'type': 'domain',
#     'integrated': 'IPR002187',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a3e2t713',
#      'protein_length': 580,
#      'source_database': 'unreviewed',
#      'organism': '853',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 465,
#          'end': 570,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00543',
#        'score': 3.2e-21}]}]},
#   {'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a3e2t713',
#      'protein_length': 580,
#      'source_database': 'unreviewed',
#      'organism': '853',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 9,
#          'end': 406,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2.7e-119}]}]}],
#  'A0A3E2UCG9': [{'metadata': {'accession': 'PF00543',
#     'name': 'Nitrogen regulatory protein P-II',
#     'source_database': 'pfam',
#     'type': 'domain',
#     'integrated': 'IPR002187',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a3e2ucg9',
#      'protein_length': 580,
#      'source_database': 'unreviewed',
#      'organism': '853',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 465,
#          'end': 570,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00543',
#        'score': 2.9e-21}]}]},
#   {'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a3e2ucg9',
#      'protein_length': 580,
#      'source_database': 'unreviewed',
#      'organism': '853',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 9,
#          'end': 405,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.7e-119}]}]}],
#  'R8VWI7': [{'metadata': {'accession': 'PF00543',
#     'name': 'Nitrogen regulatory protein P-II',
#     'source_database': 'pfam',
#     'type': 'domain',
#     'integrated': 'IPR002187',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'r8vwi7',
#      'protein_length': 574,
#      'source_database': 'unreviewed',
#      'organism': '1203606',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 461,
#          'end': 565,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00543',
#        'score': 1.8e-19}]}]},
#   {'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'r8vwi7',
#      'protein_length': 574,
#      'source_database': 'unreviewed',
#      'organism': '1203606',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 15,
#          'end': 407,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 9.7e-121}]}]}],
#  'A0A1Y4L5P0': [{'metadata': {'accession': 'PF00543',
#     'name': 'Nitrogen regulatory protein P-II',
#     'source_database': 'pfam',
#     'type': 'domain',
#     'integrated': 'IPR002187',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1y4l5p0',
#      'protein_length': 573,
#      'source_database': 'unreviewed',
#      'organism': '501571',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 460,
#          'end': 564,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00543',
#        'score': 9.9e-20}]}]},
#   {'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1y4l5p0',
#      'protein_length': 573,
#      'source_database': 'unreviewed',
#      'organism': '501571',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 15,
#          'end': 407,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 9e-121}]}]}],
#  'A0A1Y4LM49': [{'metadata': {'accession': 'PF00543',
#     'name': 'Nitrogen regulatory protein P-II',
#     'source_database': 'pfam',
#     'type': 'domain',
#     'integrated': 'IPR002187',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1y4lm49',
#      'protein_length': 574,
#      'source_database': 'unreviewed',
#      'organism': '501571',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 461,
#          'end': 565,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00543',
#        'score': 1.8e-19}]}]},
#   {'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1y4lm49',
#      'protein_length': 574,
#      'source_database': 'unreviewed',
#      'organism': '501571',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 15,
#          'end': 407,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 9.4e-121}]}]}],
#  'D0MFE8': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'd0mfe8',
#      'protein_length': 461,
#      'source_database': 'unreviewed',
#      'organism': '518766',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 46,
#          'end': 445,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 5.3e-126}]}]}],
#  'Q1H0G2': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'q1h0g2',
#      'protein_length': 437,
#      'source_database': 'unreviewed',
#      'organism': '265072',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 36,
#          'end': 417,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 3.4e-110}]}]}],
#  'A0A7G5DKA9': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a7g5dka9',
#      'protein_length': 431,
#      'source_database': 'unreviewed',
#      'organism': '2726956',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 28,
#          'end': 413,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 9.2e-113}]}]}],
#  'Q0VPH4': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'q0vph4',
#      'protein_length': 436,
#      'source_database': 'unreviewed',
#      'organism': '393595',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 29,
#          'end': 410,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 4.3e-110}]}]}],
#  'D5ELM4': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'd5elm4',
#      'protein_length': 462,
#      'source_database': 'unreviewed',
#      'organism': '583355',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 44,
#          'end': 447,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1e-120}]}]}],
#  'A0A2G6JLT9': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a2g6jlt9',
#      'protein_length': 402,
#      'source_database': 'unreviewed',
#      'organism': '207954',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 19,
#          'end': 395,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 4.2e-88}]}]}],
#  'A0A7U8C2Y6': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a7u8c2y6',
#      'protein_length': 402,
#      'source_database': 'unreviewed',
#      'organism': '207954',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 19,
#          'end': 395,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2.8e-86}]}]}],
#  'A0A9J9ES23': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a9j9es23',
#      'protein_length': 402,
#      'source_database': 'unreviewed',
#      'organism': '3042615',
#      'in_alphafold': False,
#      'entry_protein_locations': [{'fragments': [{'start': 19,
#          'end': 394,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 8e-86}]}]}],
#  'Q1Z695': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'q1z695',
#      'protein_length': 402,
#      'source_database': 'unreviewed',
#      'organism': '314280',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 19,
#          'end': 395,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 3.7e-85}]}]}],
#  'Q6LKC8': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'q6lkc8',
#      'protein_length': 405,
#      'source_database': 'unreviewed',
#      'organism': '298386',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 22,
#          'end': 398,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 1.7e-85}]}]}],
#  'R9PMC6': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'r9pmc6',
#      'protein_length': 400,
#      'source_database': 'unreviewed',
#      'organism': '1331007',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 19,
#          'end': 394,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2.7e-85}]}]}],
#  'A0A2N7L7C8': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a2n7l7c8',
#      'protein_length': 402,
#      'source_database': 'unreviewed',
#      'organism': '188144',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 19,
#          'end': 395,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 3e-85}]}]}],
#  'A0A1E5C7W4': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a0a1e5c7w4',
#      'protein_length': 402,
#      'source_database': 'unreviewed',
#      'organism': '1185651',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 19,
#          'end': 395,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 3.2e-85}]}]}],
#  'A4BEP1': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'a4bep1',
#      'protein_length': 408,
#      'source_database': 'unreviewed',
#      'organism': '314283',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 23,
#          'end': 401,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 2.2e-84}]}]}],
#  'F0S3Z6': [{'metadata': {'accession': 'PF00909',
#     'name': 'Ammonium Transporter Family',
#     'source_database': 'pfam',
#     'type': 'family',
#     'integrated': 'IPR024041',
#     'member_databases': None,
#     'go_terms': None},
#    'proteins': [{'accession': 'f0s3z6',
#      'protein_length': 406,
#      'source_database': 'unreviewed',
#      'organism': '868864',
#      'in_alphafold': True,
#      'entry_protein_locations': [{'fragments': [{'start': 16,
#          'end': 399,
#          'dc-status': 'CONTINUOUS'}],
#        'representative': False,
#        'model': 'PF00909',
#        'score': 8.7e-94}]}]}],
#  ...}

# %%
domain_info = []
name = []
length = []
sted = []
domain_dictionary ={}
for itom in idsfromtree:

    for item in interpro_results_extra[itom]:
        # domain_id = item["metadata"]["proteins"]["accession"]  # Extract domain ID
        domain_name = item["metadata"]["name"]  # Extract domain name
        name.append(domain_name)
        print(domain_name)
        protein_lenth = item["proteins"][0]["protein_length"]
        length.append(protein_lenth)
        print(protein_lenth)
        str_end = item["proteins"][0]['entry_protein_locations'][0]["fragments"]
        sted.append(str_end)
        print(str_end)
        domain_info.append((f"{itom}: {domain_name} {str_end} {protein_lenth}"))
        domain_dictionary[str(itom)] = (domain_name, name, str_end, protein_lenth)
# Out:
# Ammonium Transporter Family
# 430
# [{'start': 35, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 34, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 430
# [{'start': 35, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 430
# [{'start': 35, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 34, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 34, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 430
# [{'start': 35, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 430
# [{'start': 35, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 430
# [{'start': 35, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 430
# [{'start': 35, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 430
# [{'start': 35, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 439
# [{'start': 45, 'end': 438, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 439
# [{'start': 45, 'end': 438, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 439
# [{'start': 45, 'end': 438, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 32, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 32, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 32, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 32, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 32, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 32, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 32, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 32, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 32, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 32, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 33, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 33, 'end': 425, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 33, 'end': 425, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 33, 'end': 425, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 32, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 32, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 32, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 32, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 435
# [{'start': 41, 'end': 434, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 34, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 432
# [{'start': 37, 'end': 430, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 430
# [{'start': 34, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 425
# [{'start': 31, 'end': 423, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 40, 'end': 432, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 416
# [{'start': 22, 'end': 414, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 34, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 34, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 34, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 34, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 34, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 34, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 34, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 430
# [{'start': 35, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 433
# [{'start': 38, 'end': 431, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 435
# [{'start': 40, 'end': 433, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 39, 'end': 432, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 423
# [{'start': 28, 'end': 421, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 423
# [{'start': 28, 'end': 421, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 423
# [{'start': 28, 'end': 421, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 36, 'end': 429, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 36, 'end': 429, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 34, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 39, 'end': 432, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 34, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 34, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 34, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 34, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 34, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 430
# [{'start': 35, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 478
# [{'start': 51, 'end': 476, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 478
# [{'start': 51, 'end': 476, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 471
# [{'start': 42, 'end': 469, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 485
# [{'start': 58, 'end': 483, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 499
# [{'start': 72, 'end': 497, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 495
# [{'start': 67, 'end': 493, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 515
# [{'start': 87, 'end': 513, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 510
# [{'start': 83, 'end': 509, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 511
# [{'start': 84, 'end': 510, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 511
# [{'start': 83, 'end': 509, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 504
# [{'start': 76, 'end': 502, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 513
# [{'start': 85, 'end': 511, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 513
# [{'start': 85, 'end': 511, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 515
# [{'start': 88, 'end': 513, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 516
# [{'start': 88, 'end': 514, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 494
# [{'start': 66, 'end': 492, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 519
# [{'start': 91, 'end': 517, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 516
# [{'start': 88, 'end': 514, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 506
# [{'start': 75, 'end': 504, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 466
# [{'start': 39, 'end': 464, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 450
# [{'start': 53, 'end': 448, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 450
# [{'start': 53, 'end': 448, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 450
# [{'start': 53, 'end': 448, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 449
# [{'start': 52, 'end': 447, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 449
# [{'start': 52, 'end': 447, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 450
# [{'start': 53, 'end': 448, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 450
# [{'start': 53, 'end': 448, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 457
# [{'start': 60, 'end': 455, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 457
# [{'start': 60, 'end': 455, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 435
# [{'start': 37, 'end': 433, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 489
# [{'start': 89, 'end': 487, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 455
# [{'start': 56, 'end': 453, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 453
# [{'start': 54, 'end': 451, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 433
# [{'start': 35, 'end': 431, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 458
# [{'start': 59, 'end': 456, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 466
# [{'start': 71, 'end': 464, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 462
# [{'start': 63, 'end': 460, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 462
# [{'start': 63, 'end': 460, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 462
# [{'start': 63, 'end': 460, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 487
# [{'start': 59, 'end': 485, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 487
# [{'start': 59, 'end': 485, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 487
# [{'start': 59, 'end': 485, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 508
# [{'start': 77, 'end': 506, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 491
# [{'start': 61, 'end': 489, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 521
# [{'start': 85, 'end': 519, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 523
# [{'start': 87, 'end': 521, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 522
# [{'start': 86, 'end': 520, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 504
# [{'start': 68, 'end': 502, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 432
# [{'start': 1, 'end': 430, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 432
# [{'start': 1, 'end': 430, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 503
# [{'start': 71, 'end': 501, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 504
# [{'start': 72, 'end': 502, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 466
# [{'start': 70, 'end': 464, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 458
# [{'start': 62, 'end': 456, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 458
# [{'start': 62, 'end': 456, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 486
# [{'start': 92, 'end': 484, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 486
# [{'start': 92, 'end': 484, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 486
# [{'start': 90, 'end': 484, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 480
# [{'start': 84, 'end': 478, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 403
# [{'start': 1, 'end': 401, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 466
# [{'start': 62, 'end': 464, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 399
# [{'start': 2, 'end': 397, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 450
# [{'start': 49, 'end': 448, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 511
# [{'start': 83, 'end': 509, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 412
# [{'start': 8, 'end': 410, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 412
# [{'start': 8, 'end': 410, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 412
# [{'start': 8, 'end': 410, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 412
# [{'start': 8, 'end': 410, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 412
# [{'start': 8, 'end': 410, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 412
# [{'start': 8, 'end': 410, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 412
# [{'start': 8, 'end': 410, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 412
# [{'start': 8, 'end': 410, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 38, 'end': 463, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 38, 'end': 463, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 38, 'end': 463, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 470
# [{'start': 43, 'end': 468, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 480
# [{'start': 53, 'end': 478, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 480
# [{'start': 53, 'end': 478, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 39, 'end': 432, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 38, 'end': 463, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 482
# [{'start': 55, 'end': 480, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 459
# [{'start': 34, 'end': 458, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 519
# [{'start': 40, 'end': 518, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 447
# [{'start': 48, 'end': 445, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 33, 'end': 430, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 480
# [{'start': 36, 'end': 478, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 480
# [{'start': 36, 'end': 478, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 480
# [{'start': 36, 'end': 478, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 480
# [{'start': 36, 'end': 478, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 480
# [{'start': 36, 'end': 478, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 480
# [{'start': 36, 'end': 478, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 480
# [{'start': 36, 'end': 478, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 509
# [{'start': 65, 'end': 507, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 482
# [{'start': 36, 'end': 480, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 510
# [{'start': 64, 'end': 508, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 482
# [{'start': 36, 'end': 480, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 482
# [{'start': 36, 'end': 480, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 482
# [{'start': 36, 'end': 480, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 493
# [{'start': 50, 'end': 491, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 499
# [{'start': 39, 'end': 497, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 506
# [{'start': 46, 'end': 504, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 509
# [{'start': 58, 'end': 507, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 501
# [{'start': 43, 'end': 499, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 480
# [{'start': 58, 'end': 478, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 454
# [{'start': 51, 'end': 452, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 453
# [{'start': 50, 'end': 451, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 450
# [{'start': 47, 'end': 448, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 468
# [{'start': 64, 'end': 466, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 453
# [{'start': 51, 'end': 451, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 453
# [{'start': 51, 'end': 451, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 451
# [{'start': 54, 'end': 449, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 450
# [{'start': 53, 'end': 448, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 453
# [{'start': 50, 'end': 451, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 448
# [{'start': 39, 'end': 446, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 454
# [{'start': 52, 'end': 452, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 475
# [{'start': 52, 'end': 472, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 475
# [{'start': 52, 'end': 472, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 474
# [{'start': 51, 'end': 471, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 475
# [{'start': 52, 'end': 472, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 475
# [{'start': 53, 'end': 473, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 475
# [{'start': 53, 'end': 473, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 439
# [{'start': 35, 'end': 438, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 439
# [{'start': 40, 'end': 438, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 442
# [{'start': 38, 'end': 440, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 511
# [{'start': 75, 'end': 509, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 510
# [{'start': 74, 'end': 508, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 510
# [{'start': 71, 'end': 508, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 453
# [{'start': 50, 'end': 451, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 508
# [{'start': 77, 'end': 506, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 485
# [{'start': 76, 'end': 483, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 442
# [{'start': 35, 'end': 440, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 442
# [{'start': 35, 'end': 440, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 438
# [{'start': 34, 'end': 436, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 445
# [{'start': 38, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 438
# [{'start': 34, 'end': 436, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 439
# [{'start': 35, 'end': 437, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 438
# [{'start': 34, 'end': 436, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 26, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 26, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 440
# [{'start': 36, 'end': 438, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 441
# [{'start': 36, 'end': 439, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 433
# [{'start': 36, 'end': 431, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 435
# [{'start': 38, 'end': 433, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 444
# [{'start': 46, 'end': 441, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 449
# [{'start': 39, 'end': 447, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 438
# [{'start': 39, 'end': 436, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 446
# [{'start': 33, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 453
# [{'start': 40, 'end': 450, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 52, 'end': 462, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 52, 'end': 462, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 52, 'end': 462, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 464
# [{'start': 51, 'end': 461, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 450
# [{'start': 37, 'end': 447, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 464
# [{'start': 51, 'end': 461, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 457
# [{'start': 43, 'end': 453, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 51, 'end': 461, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 466
# [{'start': 52, 'end': 462, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 463
# [{'start': 50, 'end': 460, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 463
# [{'start': 51, 'end': 460, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 446
# [{'start': 33, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 452
# [{'start': 39, 'end': 449, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 452
# [{'start': 39, 'end': 449, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 452
# [{'start': 39, 'end': 449, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 452
# [{'start': 39, 'end': 449, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 452
# [{'start': 39, 'end': 449, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 470
# [{'start': 66, 'end': 467, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 438
# [{'start': 41, 'end': 437, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 438
# [{'start': 41, 'end': 437, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 438
# [{'start': 41, 'end': 437, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 492
# [{'start': 90, 'end': 487, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 458
# [{'start': 56, 'end': 453, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 32, 'end': 423, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 461
# [{'start': 60, 'end': 459, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 479
# [{'start': 78, 'end': 477, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 417
# [{'start': 23, 'end': 415, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 417
# [{'start': 23, 'end': 415, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 41, 'end': 432, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 32, 'end': 425, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 32, 'end': 425, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 441
# [{'start': 13, 'end': 408, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 437
# [{'start': 7, 'end': 404, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 525
# [{'start': 66, 'end': 465, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 558
# [{'start': 106, 'end': 502, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 545
# [{'start': 97, 'end': 503, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 420
# [{'start': 30, 'end': 418, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 449
# [{'start': 48, 'end': 447, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 36, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 451
# [{'start': 57, 'end': 449, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 433
# [{'start': 43, 'end': 431, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 433
# [{'start': 38, 'end': 430, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 436
# [{'start': 39, 'end': 434, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 466
# [{'start': 62, 'end': 463, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 449
# [{'start': 53, 'end': 447, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 443
# [{'start': 47, 'end': 439, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 446
# [{'start': 50, 'end': 442, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 447
# [{'start': 50, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 482
# [{'start': 82, 'end': 478, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 439
# [{'start': 44, 'end': 437, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 471
# [{'start': 81, 'end': 469, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 471
# [{'start': 81, 'end': 469, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 75, 'end': 462, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 433
# [{'start': 38, 'end': 431, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 39, 'end': 432, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 443
# [{'start': 48, 'end': 441, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 443
# [{'start': 48, 'end': 441, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 437
# [{'start': 42, 'end': 435, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 442
# [{'start': 40, 'end': 440, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 503
# [{'start': 106, 'end': 501, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 503
# [{'start': 106, 'end': 501, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 500
# [{'start': 103, 'end': 498, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 500
# [{'start': 103, 'end': 498, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 505
# [{'start': 108, 'end': 503, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 504
# [{'start': 107, 'end': 502, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 466
# [{'start': 71, 'end': 464, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 439
# [{'start': 31, 'end': 436, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 462
# [{'start': 54, 'end': 459, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 436
# [{'start': 41, 'end': 434, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 436
# [{'start': 41, 'end': 434, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 439
# [{'start': 35, 'end': 437, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 71, 'end': 462, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 71, 'end': 462, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 460
# [{'start': 66, 'end': 457, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 71, 'end': 462, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 71, 'end': 462, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 71, 'end': 462, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 71, 'end': 462, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 71, 'end': 462, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 71, 'end': 462, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 35, 'end': 425, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 463
# [{'start': 72, 'end': 461, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 470
# [{'start': 75, 'end': 467, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 491
# [{'start': 97, 'end': 489, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 445
# [{'start': 50, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 402
# [{'start': 7, 'end': 400, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 69, 'end': 459, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 430
# [{'start': 35, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 430
# [{'start': 35, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 430
# [{'start': 35, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 433
# [{'start': 37, 'end': 430, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 433
# [{'start': 37, 'end': 430, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 432
# [{'start': 37, 'end': 429, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 432
# [{'start': 37, 'end': 429, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 436
# [{'start': 32, 'end': 434, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 35, 'end': 432, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 35, 'end': 432, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 436
# [{'start': 37, 'end': 434, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 456
# [{'start': 37, 'end': 452, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 472
# [{'start': 62, 'end': 468, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 419
# [{'start': 13, 'end': 417, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 446
# [{'start': 37, 'end': 444, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 34, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 29, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 445
# [{'start': 46, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 437
# [{'start': 38, 'end': 435, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 412
# [{'start': 14, 'end': 410, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 26, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 30, 'end': 429, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 26, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 437
# [{'start': 37, 'end': 435, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 32, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 32, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 32, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 443
# [{'start': 44, 'end': 440, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 33, 'end': 429, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 460
# [{'start': 62, 'end': 458, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 33, 'end': 429, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 561
# [{'start': 141, 'end': 536, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 432
# [{'start': 24, 'end': 417, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 392
# [{'start': 7, 'end': 388, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 392
# [{'start': 7, 'end': 388, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 392
# [{'start': 7, 'end': 388, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 393
# [{'start': 7, 'end': 389, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 393
# [{'start': 7, 'end': 389, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 392
# [{'start': 7, 'end': 388, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 402
# [{'start': 8, 'end': 400, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 443
# [{'start': 50, 'end': 440, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 433
# [{'start': 35, 'end': 431, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 433
# [{'start': 35, 'end': 431, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 433
# [{'start': 35, 'end': 431, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 508
# [{'start': 89, 'end': 505, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 529
# [{'start': 110, 'end': 526, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 508
# [{'start': 89, 'end': 505, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 508
# [{'start': 89, 'end': 505, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 514
# [{'start': 95, 'end': 511, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 508
# [{'start': 89, 'end': 505, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 497
# [{'start': 80, 'end': 494, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 481
# [{'start': 63, 'end': 478, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 481
# [{'start': 63, 'end': 478, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 490
# [{'start': 75, 'end': 487, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 493
# [{'start': 57, 'end': 490, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 484
# [{'start': 56, 'end': 483, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 496
# [{'start': 93, 'end': 494, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 514
# [{'start': 92, 'end': 512, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 480
# [{'start': 69, 'end': 476, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 456
# [{'start': 42, 'end': 454, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 442
# [{'start': 44, 'end': 441, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 390
# [{'start': 1, 'end': 388, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 411
# [{'start': 10, 'end': 407, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 444
# [{'start': 38, 'end': 442, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 404
# [{'start': 9, 'end': 402, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 33, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 33, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 32, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 33, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 32, 'end': 425, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 433
# [{'start': 37, 'end': 430, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 426
# [{'start': 28, 'end': 423, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 432
# [{'start': 30, 'end': 429, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 427
# [{'start': 31, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 425
# [{'start': 31, 'end': 422, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 406
# [{'start': 9, 'end': 402, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 405
# [{'start': 10, 'end': 402, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 405
# [{'start': 10, 'end': 402, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 405
# [{'start': 10, 'end': 402, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 405
# [{'start': 10, 'end': 402, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 405
# [{'start': 10, 'end': 402, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 407
# [{'start': 9, 'end': 404, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 407
# [{'start': 13, 'end': 405, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 408
# [{'start': 11, 'end': 406, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 429
# [{'start': 41, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 419
# [{'start': 29, 'end': 415, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 412
# [{'start': 7, 'end': 405, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 412
# [{'start': 7, 'end': 405, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 419
# [{'start': 14, 'end': 412, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 415
# [{'start': 8, 'end': 407, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 417
# [{'start': 9, 'end': 409, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 417
# [{'start': 8, 'end': 409, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 414
# [{'start': 10, 'end': 407, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 414
# [{'start': 10, 'end': 407, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 448
# [{'start': 8, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 448
# [{'start': 8, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 442
# [{'start': 8, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 416
# [{'start': 9, 'end': 407, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 435
# [{'start': 35, 'end': 432, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 459
# [{'start': 40, 'end': 449, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 459
# [{'start': 40, 'end': 449, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 440
# [{'start': 19, 'end': 429, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 473
# [{'start': 42, 'end': 462, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 468
# [{'start': 45, 'end': 455, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 474
# [{'start': 42, 'end': 449, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 474
# [{'start': 42, 'end': 449, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 481
# [{'start': 52, 'end': 466, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 398
# [{'start': 7, 'end': 395, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 418
# [{'start': 29, 'end': 417, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 410
# [{'start': 7, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 410
# [{'start': 7, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 410
# [{'start': 7, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 401
# [{'start': 4, 'end': 399, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 401
# [{'start': 4, 'end': 399, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 405
# [{'start': 8, 'end': 402, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 410
# [{'start': 11, 'end': 405, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 32, 'end': 430, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 409
# [{'start': 7, 'end': 405, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 409
# [{'start': 7, 'end': 405, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 438
# [{'start': 33, 'end': 425, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 461
# [{'start': 36, 'end': 431, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 420
# [{'start': 11, 'end': 409, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 420
# [{'start': 11, 'end': 409, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 419
# [{'start': 9, 'end': 408, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 420
# [{'start': 7, 'end': 404, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 420
# [{'start': 10, 'end': 406, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 403
# [{'start': 7, 'end': 401, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 437
# [{'start': 37, 'end': 435, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 35, 'end': 432, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 433
# [{'start': 8, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 8, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 467
# [{'start': 39, 'end': 434, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 472
# [{'start': 44, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 458
# [{'start': 28, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 470
# [{'start': 40, 'end': 438, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 494
# [{'start': 54, 'end': 452, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 494
# [{'start': 54, 'end': 452, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 495
# [{'start': 55, 'end': 453, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 467
# [{'start': 27, 'end': 425, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 468
# [{'start': 40, 'end': 438, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 407
# [{'start': 10, 'end': 406, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 406
# [{'start': 8, 'end': 405, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 401
# [{'start': 7, 'end': 399, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 401
# [{'start': 7, 'end': 399, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 402
# [{'start': 7, 'end': 400, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 402
# [{'start': 7, 'end': 400, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 400
# [{'start': 7, 'end': 398, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 400
# [{'start': 7, 'end': 398, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 405
# [{'start': 8, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 405
# [{'start': 7, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 405
# [{'start': 7, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 405
# [{'start': 7, 'end': 402, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 405
# [{'start': 7, 'end': 402, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 404
# [{'start': 7, 'end': 402, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 403
# [{'start': 7, 'end': 401, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 405
# [{'start': 7, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 407
# [{'start': 7, 'end': 405, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 452
# [{'start': 48, 'end': 448, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 443
# [{'start': 37, 'end': 437, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 443
# [{'start': 37, 'end': 437, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 444
# [{'start': 37, 'end': 438, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 441
# [{'start': 34, 'end': 435, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 445
# [{'start': 39, 'end': 439, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 436
# [{'start': 34, 'end': 433, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 436
# [{'start': 34, 'end': 433, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 441
# [{'start': 32, 'end': 432, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 397
# [{'start': 9, 'end': 395, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 397
# [{'start': 9, 'end': 395, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 397
# [{'start': 9, 'end': 395, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 516
# [{'start': 72, 'end': 513, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 521
# [{'start': 75, 'end': 518, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 502
# [{'start': 78, 'end': 499, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 502
# [{'start': 82, 'end': 499, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 543
# [{'start': 25, 'end': 445, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 537
# [{'start': 26, 'end': 159, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 472
# [{'start': 9, 'end': 416, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 527
# [{'start': 39, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 527
# [{'start': 39, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 527
# [{'start': 39, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 509
# [{'start': 39, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 509
# [{'start': 39, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 509
# [{'start': 39, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 490
# [{'start': 31, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 510
# [{'start': 37, 'end': 442, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 562
# [{'start': 54, 'end': 459, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 562
# [{'start': 54, 'end': 459, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 561
# [{'start': 54, 'end': 459, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 561
# [{'start': 53, 'end': 458, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 544
# [{'start': 53, 'end': 458, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 542
# [{'start': 52, 'end': 457, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 542
# [{'start': 52, 'end': 457, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 497
# [{'start': 11, 'end': 412, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 503
# [{'start': 19, 'end': 418, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 503
# [{'start': 19, 'end': 418, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 503
# [{'start': 17, 'end': 421, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 514
# [{'start': 33, 'end': 435, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 496
# [{'start': 22, 'end': 425, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 504
# [{'start': 27, 'end': 430, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 474
# [{'start': 23, 'end': 425, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 474
# [{'start': 23, 'end': 425, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 525
# [{'start': 31, 'end': 434, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 531
# [{'start': 30, 'end': 433, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 575
# [{'start': 30, 'end': 433, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 489
# [{'start': 19, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 463
# [{'start': 16, 'end': 419, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 492
# [{'start': 20, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 498
# [{'start': 47, 'end': 449, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 489
# [{'start': 32, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 493
# [{'start': 32, 'end': 444, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 502
# [{'start': 33, 'end': 444, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 491
# [{'start': 32, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 676
# [{'start': 33, 'end': 444, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 492
# [{'start': 40, 'end': 447, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 501
# [{'start': 30, 'end': 436, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 480
# [{'start': 29, 'end': 435, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 514
# [{'start': 30, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 499
# [{'start': 34, 'end': 444, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 581
# [{'start': 23, 'end': 274, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 471
# [{'start': 15, 'end': 434, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 574
# ...
# Ammonium Transporter Family
# 450
# [{'start': 38, 'end': 443, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 492
# [{'start': 78, 'end': 484, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 482
# [{'start': 78, 'end': 474, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 483
# [{'start': 78, 'end': 475, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 489
# [{'start': 83, 'end': 467, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 489
# [{'start': 74, 'end': 458, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 482
# [{'start': 66, 'end': 454, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 496
# [{'start': 73, 'end': 468, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 496
# [{'start': 73, 'end': 468, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 505
# [{'start': 80, 'end': 475, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 504
# [{'start': 89, 'end': 474, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 504
# [{'start': 89, 'end': 474, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 496
# [{'start': 82, 'end': 467, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 484
# [{'start': 65, 'end': 476, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 478
# [{'start': 61, 'end': 451, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 478
# [{'start': 61, 'end': 451, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 524
# [{'start': 82, 'end': 498, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 524
# [{'start': 82, 'end': 498, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 534
# [{'start': 85, 'end': 503, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 556
# [{'start': 107, 'end': 526, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 541
# [{'start': 93, 'end': 509, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 509
# [{'start': 79, 'end': 491, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 504
# [{'start': 74, 'end': 486, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 499
# [{'start': 29, 'end': 439, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 505
# [{'start': 51, 'end': 445, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 669
# [{'start': 56, 'end': 232, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 506
# [{'start': 58, 'end': 474, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 492
# [{'start': 67, 'end': 483, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 408
# [{'start': 10, 'end': 400, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 490
# [{'start': 59, 'end': 482, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 490
# [{'start': 59, 'end': 482, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 469
# [{'start': 55, 'end': 460, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 507
# [{'start': 58, 'end': 473, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 506
# [{'start': 58, 'end': 473, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 410
# [{'start': 11, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 410
# [{'start': 11, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 410
# [{'start': 11, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 409
# [{'start': 11, 'end': 402, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 410
# [{'start': 11, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 405
# [{'start': 11, 'end': 398, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 410
# [{'start': 11, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 410
# [{'start': 11, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 462
# [{'start': 11, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 408
# [{'start': 11, 'end': 400, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 417
# [{'start': 11, 'end': 408, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 402
# [{'start': 1, 'end': 394, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 408
# [{'start': 9, 'end': 400, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 411
# [{'start': 9, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 399
# [{'start': 1, 'end': 388, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 498
# [{'start': 102, 'end': 489, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 498
# [{'start': 102, 'end': 489, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 462
# [{'start': 53, 'end': 454, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 394
# [{'start': 13, 'end': 387, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 34, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 31, 'end': 425, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 436
# [{'start': 36, 'end': 430, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 611
# [{'start': 9, 'end': 385, 'dc-status': 'CONTINUOUS'}]
# Diguanylate cyclase, GGDEF domain
# 611
# [{'start': 448, 'end': 606, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 432
# [{'start': 32, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 436
# [{'start': 36, 'end': 430, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 433
# [{'start': 41, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 443
# [{'start': 45, 'end': 437, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 417
# [{'start': 11, 'end': 403, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 444
# [{'start': 46, 'end': 435, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 439
# [{'start': 43, 'end': 431, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 430
# [{'start': 35, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 421
# [{'start': 20, 'end': 412, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 421
# [{'start': 20, 'end': 412, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 458
# [{'start': 62, 'end': 450, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 474
# [{'start': 55, 'end': 458, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 437
# [{'start': 13, 'end': 417, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 439
# [{'start': 15, 'end': 419, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 437
# [{'start': 13, 'end': 417, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 437
# [{'start': 13, 'end': 417, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 13, 'end': 417, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 428
# [{'start': 8, 'end': 412, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 436
# [{'start': 16, 'end': 420, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 436
# [{'start': 16, 'end': 420, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 420
# [{'start': 10, 'end': 407, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 425
# [{'start': 10, 'end': 410, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 10, 'end': 409, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 10, 'end': 408, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 444
# [{'start': 16, 'end': 420, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 444
# [{'start': 16, 'end': 420, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 479
# [{'start': 41, 'end': 448, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 520
# [{'start': 69, 'end': 480, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 544
# [{'start': 94, 'end': 505, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 478
# [{'start': 43, 'end': 447, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 476
# [{'start': 42, 'end': 446, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 452
# [{'start': 22, 'end': 431, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 489
# [{'start': 53, 'end': 455, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 514
# [{'start': 51, 'end': 476, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 498
# [{'start': 49, 'end': 471, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 504
# [{'start': 53, 'end': 476, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 466
# [{'start': 18, 'end': 444, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 460
# [{'start': 18, 'end': 439, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 782
# [{'start': 17, 'end': 451, 'dc-status': 'CONTINUOUS'}]
# NPL4 family
# 782
# [{'start': 527, 'end': 649, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 539
# [{'start': 76, 'end': 511, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 477
# [{'start': 56, 'end': 474, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 478
# [{'start': 59, 'end': 470, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 509
# [{'start': 84, 'end': 502, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 441
# [{'start': 17, 'end': 440, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 433
# [{'start': 5, 'end': 432, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 5, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 434
# [{'start': 2, 'end': 432, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 521
# [{'start': 53, 'end': 479, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 521
# [{'start': 53, 'end': 479, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 437
# [{'start': 32, 'end': 425, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 577
# [{'start': 30, 'end': 448, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 607
# [{'start': 26, 'end': 301, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 528
# [{'start': 110, 'end': 517, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 28, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 431
# [{'start': 21, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 466
# [{'start': 25, 'end': 440, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 533
# [{'start': 45, 'end': 450, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 508
# [{'start': 74, 'end': 477, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 506
# [{'start': 63, 'end': 469, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 458
# [{'start': 33, 'end': 456, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 462
# [{'start': 27, 'end': 461, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 570
# [{'start': 38, 'end': 530, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 473
# [{'start': 41, 'end': 459, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 467
# [{'start': 18, 'end': 441, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 499
# [{'start': 57, 'end': 482, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 498
# [{'start': 57, 'end': 481, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 505
# [{'start': 54, 'end': 481, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 482
# [{'start': 31, 'end': 435, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 449
# [{'start': 31, 'end': 435, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 482
# [{'start': 31, 'end': 435, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 449
# [{'start': 31, 'end': 435, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 453
# [{'start': 32, 'end': 435, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 453
# [{'start': 32, 'end': 435, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 453
# [{'start': 32, 'end': 435, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 13, 'end': 423, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 458
# [{'start': 13, 'end': 416, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 415
# [{'start': 18, 'end': 404, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 458
# [{'start': 19, 'end': 413, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 407
# [{'start': 8, 'end': 390, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 447
# [{'start': 33, 'end': 426, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 458
# [{'start': 27, 'end': 427, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 454
# [{'start': 30, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 456
# [{'start': 30, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 465
# [{'start': 33, 'end': 448, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 444
# [{'start': 20, 'end': 415, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 454
# [{'start': 20, 'end': 430, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 451
# [{'start': 20, 'end': 430, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 457
# [{'start': 20, 'end': 433, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 466
# [{'start': 22, 'end': 439, 'dc-status': 'CONTINUOUS'}]
# Nitrogen regulatory protein P-II
# 562
# [{'start': 452, 'end': 555, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 562
# [{'start': 22, 'end': 412, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 457
# [{'start': 22, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 445
# [{'start': 21, 'end': 419, 'dc-status': 'CONTINUOUS'}]
# Nitrogen regulatory protein P-II
# 584
# [{'start': 474, 'end': 578, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 584
# [{'start': 20, 'end': 425, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 475
# [{'start': 22, 'end': 419, 'dc-status': 'CONTINUOUS'}]
# Nitrogen regulatory protein P-II
# 558
# [{'start': 448, 'end': 552, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 558
# [{'start': 21, 'end': 406, 'dc-status': 'CONTINUOUS'}]
# Nitrogen regulatory protein P-II
# 548
# [{'start': 438, 'end': 542, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 548
# [{'start': 22, 'end': 408, 'dc-status': 'CONTINUOUS'}]
# Nitrogen regulatory protein P-II
# 550
# [{'start': 440, 'end': 544, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 550
# [{'start': 21, 'end': 407, 'dc-status': 'CONTINUOUS'}]
# Nitrogen regulatory protein P-II
# 555
# [{'start': 445, 'end': 549, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 555
# [{'start': 23, 'end': 412, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 442
# [{'start': 20, 'end': 413, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 441
# [{'start': 20, 'end': 416, 'dc-status': 'CONTINUOUS'}]
# Nitrogen regulatory protein P-II
# 550
# [{'start': 440, 'end': 543, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 550
# [{'start': 15, 'end': 411, 'dc-status': 'CONTINUOUS'}]
# Nitrogen regulatory protein P-II
# 572
# [{'start': 462, 'end': 565, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 572
# [{'start': 24, 'end': 423, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 456
# [{'start': 19, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 470
# [{'start': 18, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 470
# [{'start': 18, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 467
# [{'start': 18, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 468
# [{'start': 18, 'end': 428, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 473
# [{'start': 27, 'end': 438, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 513
# [{'start': 15, 'end': 419, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 516
# [{'start': 18, 'end': 422, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 468
# [{'start': 19, 'end': 424, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 457
# [{'start': 19, 'end': 423, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 449
# [{'start': 19, 'end': 423, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 416
# [{'start': 30, 'end': 408, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 408
# [{'start': 28, 'end': 405, 'dc-status': 'CONTINUOUS'}]
# Ammonium Transporter Family
# 411
# [{'start': 28, 'end': 407, 'dc-status': 'CONTINUOUS'}]

# %%
domain_dictionary
# Out:
# {'A0A066ZRQ5': ('Diguanylate cyclase, GGDEF domain',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 448, 'end': 606, 'dc-status': 'CONTINUOUS'}],
#   611),
#  'A0A173R3X4': ('Ammonium Transporter Family',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 16, 'end': 411, 'dc-status': 'CONTINUOUS'}],
#   581),
#  'A0A1Y4L5P0': ('Ammonium Transporter Family',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 15, 'end': 407, 'dc-status': 'CONTINUOUS'}],
#   573),
#  'A0A1Y4LM49': ('Ammonium Transporter Family',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 15, 'end': 407, 'dc-status': 'CONTINUOUS'}],
#   574),
#  'A0A2C9CK98': ('Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 565, 'end': 674, 'dc-status': 'CONTINUOUS'}],
#   679),
#  'A0A2G3DSU6': ('Ammonium Transporter Family',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 11, 'end': 406, 'dc-status': 'CONTINUOUS'}],
#   581),
#  'A0A2G3E8V2': ('Ammonium Transporter Family',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 11, 'end': 406, 'dc-status': 'CONTINUOUS'}],
#   581),
#  'A0A2K3DQF8': ('NPL4 family',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 527, 'end': 649, 'dc-status': 'CONTINUOUS'}],
#   782),
#  'A0A317G0I6': ('Ammonium Transporter Family',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 16, 'end': 420, 'dc-status': 'CONTINUOUS'}],
#   591),
#  'A0A3E2T713': ('Ammonium Transporter Family',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 9, 'end': 406, 'dc-status': 'CONTINUOUS'}],
#   580),
#  'A0A3E2TW06': ('Ammonium Transporter Family',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 9, 'end': 405, 'dc-status': 'CONTINUOUS'}],
#   579),
#  'A0A3E2UCG9': ('Ammonium Transporter Family',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 9, 'end': 405, 'dc-status': 'CONTINUOUS'}],
#   580),
#  'A0A3E2UHE6': ('Ammonium Transporter Family',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 9, 'end': 405, 'dc-status': 'CONTINUOUS'}],
#   579),
#  'A0A3E2VY88': ('Ammonium Transporter Family',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
# ...
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 565, 'end': 674, 'dc-status': 'CONTINUOUS'}],
#   679),
#  'R8VWI7': ('Ammonium Transporter Family',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 15, 'end': 407, 'dc-status': 'CONTINUOUS'}],
#   574),
#  'W0E077': ('Ammonium Transporter Family',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 1, 'end': 393, 'dc-status': 'CONTINUOUS'}],
#   720),
#  'W0JIB3': ('Ammonium Transporter Family',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 20, 'end': 425, 'dc-status': 'CONTINUOUS'}],
#   584),
#  'W7QGM4': ('PAS domain',
#   ['Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'NPL4 family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS fold',
#    'PAS fold',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Adenylate and Guanylate cyclase catalytic domain',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Histidine kinase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Ammonium Transporter Family',
#    'Diguanylate cyclase, GGDEF domain',
#    'His Kinase A (phospho-acceptor) domain',
#    'Ammonium Transporter Family',
#    'Histidine kinase-, DNA gyrase B-, and HSP90-like ATPase',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'Methyl-accepting chemotaxis protein (MCP) signalling domain',
#    'Ammonium Transporter Family',
#    'Nitrogen regulatory protein P-II',
#    'Ammonium Transporter Family',
#    'EAL domain',
#    'Ammonium Transporter Family',
#    'PAS fold',
#    'Diguanylate cyclase, GGDEF domain',
#    'PAS domain'],
#   [{'start': 457, 'end': 562, 'dc-status': 'CONTINUOUS'}],
#   1136)}

# %%
new_dom_dict_extra = {}

for leaf in tr:
    for t in domain_info:
        if leaf.name.split(' ')[-1] == t.split(': ')[0]:
            s = t.split(': ')[1:]
            new_dom_dict_extra[str(leaf)] = s

# %%
len(new_dom_dict_extra)
# Out:
# 1299

# %%
new_dom_dict_extra
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 new_dom_dict_extra
#
# NameError: name 'new_dom_dict_extra' is not defined

# %%
with open('new_dom_dict_extra.txt', 'w') as fp:
    for ite in new_dom_dict_extra:
        # write each item on a new line
        fp.write("%s\n" % ite)
    print('Done')
# Out:
# Done

# %%
u.search('A0A066ZRQ5', frmt = 'tsv', columns = "ft_domain")
# Out:
# 'Domain [FT]\nDOMAIN 478..611; /note="GGDEF"; /evidence="ECO:0000259|PROSITE:PS50887"\n'

# %%
treepath = Path("EYROOTED.tree")  # transporter family tree, Newick format
annopath = Path("all_annotations.csv")     # annotations for some family members
stem = "st_split"
tr = Tree('EYROOTED.tree')

# %%
# Load the tree
# We have these as functions so that we can annotate/render a clean tree each time
def load_tree():
    tree = Tree(str(treepath))
    return tree

# Load the annotation
def load_annotation():
    anno = pd.read_csv(annopath)
    return anno

# The function lets us return the tree and its corresponding annotation,
# where the leaves of this specific tree object are present in the
# annotation dataframe, and so can be manipulated easily.
def annotate_tree():
    tree = load_tree()
    anno = load_annotation()

    leaves = []  # Will hold leaves for the tree where they match the annotation row, or None if there is none
    
    for id in anno["0"]:               # iterate over annotations
        for leaf in tree.iter_leaves():  # iterate over all leaves in the tree
            assigned = False
            if id in str(leaf):
                leaves.append(leaf)
                assigned = True
                break
        if not assigned:
            leaves.append(None)
    
    anno["leaves"] = leaves

    return tree, anno

# %%
# # Key by UniProt ID, values are the leaf, ft_domain information, and sequence length as
# # (leaf, ft_info, length)
# domain_dict = {}

# # Iterate over leaves and query UniProt
# # Assume that the last part of the string is the accession ID at UniProt
# # (we also need to strip the final quote)
# for leaf in tqdm(tree.iter_leaves()):
accession = str(leaf).split()[-1][:-1]
#     result = u.search(accession, frmt = 'tsv', columns = "ft_domain")
#     reslen = u.search(accession, frmt = 'tsv', columns = "length")
#     if (reslen is None) or (reslen.strip() == "Length"):
#         length = None
#     else:
#         length = int(reslen.split()[-1].strip())
#     domain_dict[str(leaf)] = (accession, result, length)

# %%
u.search('A0A066ZRQ5', frmt = 'tsv', columns = "ft_domain")


"A0A833GZR2: Ammonium Transporter Family [{'start': 9, 'end': 401, 'dc-status': 'CONTINUOUS'}] 681",
# Out:
# 'Domain [FT]\nDOMAIN 478..611; /note="GGDEF"; /evidence="ECO:0000259|PROSITE:PS50887"\n'

# %%
for doms in domain_info:
    id = doms.split(':')[0]
    reslen = u.search(id, frmt = 'tsv', columns = "length")
    if (reslen is None) or (reslen.strip() == "Length"):
        length = None
    else:
        length = int(reslen.split()[-1].strip())

# %%
def result_to_face(data, fontsize=2):
    """Return a SeqMotifFace, based on the passed UniProt result"""
    # domain_name, str_end, protein_lenth = data  # split tuple
    motifs = []
    # data = sted.split("\n")[-1].strip()
    domains = domain_info
    for domain in domains:
        e = domain.split(", 'dc-st")[0]
        # print(e)
        end = int(e.split("d': ")[1])
        st = e.split("rt': ")[1]
        start = int(st.split(", 'e")[0])
        # start, end = tuple([int(_) for _ in se[0].split(", 'end': ")])
        domdata = domain.split(' [')[0]
        name = domdata.split(": ")[1]
        # seq.start, seq.end, shape, width, height, fgcolor, bgcolor
        if name == "Ammonium transporter Family":
            motifs.append([start, end, "[]", None, 10, "black", "blue", f"arial|{fontsize}|white|{name}"])
        else:
            motifs.append([start, end, "[]", None, 10, "black", "red", f"arial|{fontsize}|white|{name}"])
        
        reslen = domain.split(' ')[-1]
        if (reslen is None) or (reslen.strip() == "Length"):
            length = None
    else:
        length = int(reslen.split()[-1].strip())
    if len(motifs):
        if length is None:
            return SeqMotifFace(seq=None, motifs=motifs, seq_format="-")
        else:
            return SeqMotifFace(seq="-" * length, motifs=motifs, seq_format="-")
    return None

# %%
tree, anno = annotate_tree()  # get clean tree

# Declare tree style
everything = TreeStyle()
everything.show_leaf_name = False
everything.mode = "c"

# One text face for each kingdom
face_dict = {"Eukaryota": TextFace("eukaryota"),
             "Bacteria": TextFace("bacteria"),
             "Archaea": TextFace("archaea")}

# Set colours for kingdoms
colour_dict = {"Eukaryota": "#FFFACD", "Bacteria": "#F0F8FF", "Archaea": "#FFE4E1"}

# Set face colours for kingdoms
colour_dict = {"Eukaryota": "#FFFACD", "Bacteria": "#F0F8FF", "Archaea": "#FFE4E1"}

# Set colours for residue types
rescolours = {"Y": "#FFCC66", "E": "#009933", "M": "#9966FF"}

# Iterate over leaves
for idx, row in tqdm(anno.iterrows()):
    # Get leaf information
    leaf = row["leaves"]
    restype = row["first"]
    fourres = row["four"]    
    kingdomname = row["kingdom"].strip()    

    # Style the leaf node
    leaf.img_style["bgcolor"] = colour_dict[kingdomname]    
    leaf.add_face(face_dict[kingdomname], 1, "aligned")

    # Add gateway residue bubble
    if restype in ("Y", "E", "M"):
        face = CircleFace(radius=20, color=rescolours[restype], style="sphere", label=restype)
        face.opacity = 0.3
        leaf.add_face(face, 1, position="float")

    # Add four residues label
    if len(fourres):
        leaf.add_face(TextFace(fourres), 2, position="float")

    # Add motifs/domains
    motifs = result_to_face(new_dom_dict_extra[str(leaf)])
    if motifs is not None:
        leaf.add_face(motifs, 0, "aligned")

tree.render(f"{stem}_domains.pdf", tree_style=everything, w=24, h=24, units="in");
# Out:
# 0it [00:00, ?it/s]

# %%
IDZ = ['A0A066ZRQ5', 'A0A173R3X4', 'A0A1Y4L5P0', 'A0A1Y4LM49']

# %%
domain_dict = {}

# Iterate over leaves and query UniProt
# Assume that the last part of the string is the accession ID at UniProt
# (we also need to strip the final quote)
for leaf in tqdm(IDZ):
    accession = str(leaf).split()[-1][:-1]
    result = u.search(accession, frmt = 'tsv', columns = "ft_domain")
    reslen = u.search(accession, frmt = 'tsv', columns = "length")
    if (reslen is None) or (reslen.strip() == "Length"):
        length = None
    else:
        length = int(reslen.split()[-1].strip())
    domain_dict[str(leaf)] = (accession, result, length)
